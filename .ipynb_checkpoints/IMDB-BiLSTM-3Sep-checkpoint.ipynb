# %%
import warnings
warnings.filterwarnings('ignore')

# Modules for data manipulation
import numpy as np
import pandas as pd

# Modules for visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
### Set some matplotlib configs for visualization
SMALL_SIZE = 12
MEDIUM_SIZE = 14
BIG_SIZE = 16
LARGE_SIZE = 20

params = {
    'figure.figsize': (16, 8),
    'font.size': SMALL_SIZE,
    'xtick.labelsize': MEDIUM_SIZE,
    'ytick.labelsize': MEDIUM_SIZE,
    'legend.fontsize': BIG_SIZE,
    'figure.titlesize': LARGE_SIZE,
    'axes.titlesize': MEDIUM_SIZE,
    'axes.labelsize': BIG_SIZE
}
plt.rcParams.update(params)

# %%
# Open the cleaned csv
df_train = pd.read_csv("./input/df_train_cleaned.csv")
df_test = pd.read_csv("./input/df_test_cleaned.csv")

# %%
df_train = pd.read_csv("./input/labeledTrainData.tsv", header=0, delimiter="\t", quoting=3)
df_train.drop('id', axis=1, inplace=True)
print('df_train.shape', df_train.shape)
df_train.head()
# Out:
# df_train.shape (25000, 2)
#    sentiment                                             review
# 0          1  "With all this stuff going down at the moment ...
# 1          1  "\"The Classic War of the Worlds\" by Timothy ...
# 2          0  "The film starts with a manager (Nicholas Bell...
# 3          0  "It must be assumed that those who praised thi...
# 4          1  "Superbly trashy and wondrously unpretentious ...

# %%
df_test = pd.read_csv("./input/testData.tsv",header=0, delimiter="\t", quoting=3)
df_test.drop('id', axis=1, inplace=True)
print('df_test.shape', df_test.shape)
df_test.head()
# Out:
# df_test.shape (25000, 1)
#                                               review
# 0  "Naturally in a film who's main themes are of ...
# 1  "This movie is a disaster within a disaster fi...
# 2  "All in all, this is a movie for kids. We saw ...
# 3  "Afraid of the Dark left me with the impressio...
# 4  "A very accurate depiction of small time mob l...

# %% [markdown]
# # Data Visualization

# %%
print("y_train distribution:")
df_train['sentiment'].value_counts()
# Out:
# y_train distribution:
# 1    12500
# 0    12500
# Name: sentiment, dtype: int64

# %% [markdown]
# # Data Cleaning
# ## 1) Filter the text

# %%
# Tools for text preprocessing
from bs4 import BeautifulSoup
import re
from nltk.corpus import stopwords

def review_to_words( raw_review ):
    # 1. Remove HTML
    review_text = BeautifulSoup(raw_review, 'lxml').get_text() 
    
    # 2. Remove non-letters with regex
    letters_only = re.sub("[^a-zA-Z]", " ", review_text) 
    
    # 3. Convert to lower case, split into individual words
    words = letters_only.lower().split()                           
    
    # 4. Create set of stopwords
    stops = set(stopwords.words("english"))                  
    
    # 5. Remove stop words
    meaningful_words = [w for w in words if not w in stops]   
    
    # 6. Join the words back into one string separated by space, 
    # and return the result.
    return( " ".join( meaningful_words ))   

df_train['review'] = df_train['review'].apply(review_to_words)
df_test["review"] = df_test["review"].apply(review_to_words)

# %%
df_train.head()
# Out:
#    sentiment                                             review
# 0          1  stuff going moment mj started listening music ...
# 1          1  classic war worlds timothy hines entertaining ...
# 2          0  film starts manager nicholas bell giving welco...
# 3          0  must assumed praised film greatest filmed oper...
# 4          1  superbly trashy wondrously unpretentious explo...

# %%
df_test.head()
# Out:
#                                               review
# 0  naturally film main themes mortality nostalgia...
# 1  movie disaster within disaster film full great...
# 2  movie kids saw tonight child loved one point k...
# 3  afraid dark left impression several different ...
# 4  accurate depiction small time mob life filmed ...

# %% [markdown]
# ## 2) Check missing data

# %%
df_train.isnull().sum()
# Out:
# sentiment    0
# review       0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# review    0
# dtype: int64

# %%
# Export to csv
df_train.to_csv('./input/df_train_cleaned.csv', index=False)
df_test.to_csv('./input/df_test_cleaned.csv', index=False)

# %% [markdown]
# # Split into x_train, y_train, x_test

# %%
y_train = df_train['sentiment']
x_train = df_train['review']
x_test = df_test['review']

# %%
y_train.head()
# Out:
# 0    1
# 1    1
# 2    0
# 3    0
# 4    1
# Name: sentiment, dtype: int64

# %%
x_train.head()
# Out:
# 0    stuff going moment mj started listening music ...
# 1    classic war worlds timothy hines entertaining ...
# 2    film starts manager nicholas bell giving welco...
# 3    must assumed praised film greatest filmed oper...
# 4    superbly trashy wondrously unpretentious explo...
# Name: review, dtype: object

# %%
x_test.head()
# Out:
# 0    naturally film main themes mortality nostalgia...
# 1    movie disaster within disaster film full great...
# 2    movie kids saw tonight child loved one point k...
# 3    afraid dark left impression several different ...
# 4    accurate depiction small time mob life filmed ...
# Name: review, dtype: object

# %% [markdown]
# # Texts Preprocessing (x_train, x_test)

# %%
# Tools for Texts Preprocessing
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 1) Tokenize (Create a word2vec dictionary to convert texts into int)

# %%
max_features = 6000
tokenizer = Tokenizer(num_words = max_features)

# Create a dictionary e.g. {'angry': 3, 'excited': 5, 'a': 1}
tokenizer.fit_on_texts(list(x_train))   
# tokenizer.word_index       # display the dictionary

# Convert texts to int
x_train_tokenized = tokenizer.texts_to_sequences(x_train)
x_test_tokenized = tokenizer.texts_to_sequences(x_test)

# %%
tokenizer.word_index
# Out:
# {'movie': 1,
#  'film': 2,
#  'one': 3,
#  'like': 4,
#  'good': 5,
#  'time': 6,
#  'even': 7,
#  'would': 8,
#  'story': 9,
#  'really': 10,
#  'see': 11,
#  'well': 12,
#  'much': 13,
#  'get': 14,
#  'bad': 15,
#  'people': 16,
#  'also': 17,
#  'first': 18,
#  'great': 19,
#  'made': 20,
#  'way': 21,
#  'make': 22,
#  'could': 23,
#  'movies': 24,
#  'think': 25,
#  'characters': 26,
#  'character': 27,
#  'watch': 28,
#  'two': 29,
#  'films': 30,
#  'seen': 31,
#  'many': 32,
#  'life': 33,
#  'plot': 34,
#  'acting': 35,
#  'never': 36,
#  'love': 37,
#  'little': 38,
#  'best': 39,
#  'show': 40,
#  'know': 41,
#  'ever': 42,
#  'man': 43,
#  'better': 44,
#  'end': 45,
#  'still': 46,
#  'say': 47,
#  'scene': 48,
#  'scenes': 49,
#  'go': 50,
#  'something': 51,
#  'back': 52,
#  'real': 53,
#  'watching': 54,
#  'though': 55,
#  'thing': 56,
#  'old': 57,
#  'years': 58,
#  'actors': 59,
#  'director': 60,
#  'work': 61,
#  'another': 62,
#  'new': 63,
#  'nothing': 64,
#  'funny': 65,
#  'actually': 66,
#  'makes': 67,
#  'look': 68,
#  'find': 69,
#  'going': 70,
#  'part': 71,
#  'lot': 72,
#  'every': 73,
#  'world': 74,
#  'cast': 75,
#  'us': 76,
#  'quite': 77,
#  'want': 78,
#  'things': 79,
#  'pretty': 80,
#  'young': 81,
#  'seems': 82,
#  'around': 83,
#  'horror': 84,
#  'got': 85,
#  'however': 86,
#  'fact': 87,
#  'take': 88,
#  'big': 89,
#  'enough': 90,
#  'long': 91,
#  'thought': 92,
#  'series': 93,
#  'may': 94,
#  'give': 95,
#  'original': 96,
#  'action': 97,
#  'right': 98,
#  'without': 99,
#  'must': 100,
#  'comedy': 101,
#  'always': 102,
#  'times': 103,
#  'point': 104,
#  'gets': 105,
#  'family': 106,
#  'come': 107,
#  'role': 108,
#  'saw': 109,
#  'almost': 110,
#  'interesting': 111,
#  'least': 112,
#  'done': 113,
#  'whole': 114,
#  'music': 115,
#  'bit': 116,
#  'guy': 117,
#  'script': 118,
#  'far': 119,
#  'making': 120,
#  'minutes': 121,
#  'feel': 122,
#  'anything': 123,
#  'last': 124,
#  'might': 125,
#  'since': 126,
#  'performance': 127,
#  'girl': 128,
#  'probably': 129,
#  'woman': 130,
#  'kind': 131,
#  'tv': 132,
#  'away': 133,
#  'yet': 134,
#  'day': 135,
#  'rather': 136,
#  'worst': 137,
#  'fun': 138,
#  'sure': 139,
#  'hard': 140,
#  'anyone': 141,
#  'played': 142,
#  'found': 143,
#  'although': 144,
#  'especially': 145,
#  'course': 146,
#  'believe': 147,
#  'screen': 148,
#  'comes': 149,
#  'looking': 150,
#  'trying': 151,
#  'set': 152,
#  'goes': 153,
#  'book': 154,
#  'looks': 155,
#  'place': 156,
#  'actor': 157,
#  'different': 158,
#  'put': 159,
#  'year': 160,
#  'money': 161,
#  'ending': 162,
#  'dvd': 163,
#  'let': 164,
#  'maybe': 165,
#  'someone': 166,
#  'true': 167,
#  'sense': 168,
#  'reason': 169,
#  'everything': 170,
#  'shows': 171,
#  'three': 172,
#  'worth': 173,
#  'job': 174,
#  'main': 175,
#  'together': 176,
#  'play': 177,
#  'watched': 178,
#  'american': 179,
#  'everyone': 180,
#  'plays': 181,
#  'john': 182,
#  'effects': 183,
#  'later': 184,
#  'audience': 185,
#  'said': 186,
#  'takes': 187,
#  'instead': 188,
#  'house': 189,
#  'beautiful': 190,
#  'seem': 191,
#  'night': 192,
#  'high': 193,
#  'version': 194,
#  'wife': 195,
#  'left': 196,
#  'father': 197,
#  'special': 198,
#  'seeing': 199,
#  'half': 200,
#  'star': 201,
#  'excellent': 202,
#  'war': 203,
#  'shot': 204,
#  'idea': 205,
#  'black': 206,
#  'nice': 207,
#  'less': 208,
#  'else': 209,
#  'mind': 210,
#  'simply': 211,
#  'read': 212,
#  'second': 213,
#  'fan': 214,
#  'men': 215,
#  'death': 216,
#  'hollywood': 217,
#  'poor': 218,
#  'help': 219,
#  'completely': 220,
#  'dead': 221,
#  'used': 222,
#  'home': 223,
#  'line': 224,
#  'either': 225,
#  'short': 226,
#  'top': 227,
#  'given': 228,
#  'kids': 229,
#  'budget': 230,
#  'try': 231,
#  'classic': 232,
#  'performances': 233,
#  'wrong': 234,
#  'women': 235,
#  'enjoy': 236,
#  'boring': 237,
#  'need': 238,
#  'rest': 239,
#  'use': 240,
#  'low': 241,
#  'production': 242,
#  'friends': 243,
#  'full': 244,
#  'camera': 245,
#  'along': 246,
#  'truly': 247,
#  'video': 248,
#  'awful': 249,
#  'couple': 250,
#  'tell': 251,
#  'next': 252,
#  'remember': 253,
#  'stupid': 254,
#  'start': 255,
#  'stars': 256,
#  'mean': 257,
#  'sex': 258,
#  'perhaps': 259,
#  'came': 260,
#  'recommend': 261,
#  'moments': 262,
#  'school': 263,
#  'episode': 264,
#  'wonderful': 265,
#  'small': 266,
#  'face': 267,
#  'understand': 268,
#  'terrible': 269,
#  'playing': 270,
#  'getting': 271,
#  'written': 272,
#  'early': 273,
#  'name': 274,
#  'often': 275,
#  'keep': 276,
#  'style': 277,
#  'perfect': 278,
#  'human': 279,
#  'person': 280,
#  'others': 281,
#  'definitely': 282,
#  'gives': 283,
#  'boy': 284,
#  'lost': 285,
#  'live': 286,
#  'lines': 287,
#  'become': 288,
#  'dialogue': 289,
#  'head': 290,
#  'finally': 291,
#  'piece': 292,
#  'yes': 293,
#  'case': 294,
#  'felt': 295,
#  'mother': 296,
#  'liked': 297,
#  'supposed': 298,
#  'children': 299,
#  'title': 300,
#  'white': 301,
#  'cinema': 302,
#  'absolutely': 303,
#  'picture': 304,
#  'sort': 305,
#  'worse': 306,
#  'went': 307,
#  'certainly': 308,
#  'entire': 309,
#  'waste': 310,
#  'killer': 311,
#  'problem': 312,
#  'oh': 313,
#  'mr': 314,
#  'evil': 315,
#  'hope': 316,
#  'entertaining': 317,
#  'friend': 318,
#  'overall': 319,
#  'called': 320,
#  'based': 321,
#  'loved': 322,
#  'fans': 323,
#  'several': 324,
#  'drama': 325,
#  'beginning': 326,
#  'lives': 327,
#  'care': 328,
#  'already': 329,
#  'dark': 330,
#  'becomes': 331,
#  'laugh': 332,
#  'example': 333,
#  'direction': 334,
#  'despite': 335,
#  'seemed': 336,
#  'throughout': 337,
#  'turn': 338,
#  'son': 339,
#  'wanted': 340,
#  'unfortunately': 341,
#  'michael': 342,
#  'history': 343,
#  'final': 344,
#  'heart': 345,
#  'fine': 346,
#  'sound': 347,
#  'b': 348,
#  'amazing': 349,
#  'child': 350,
#  'humor': 351,
#  'lead': 352,
#  'guess': 353,
#  'totally': 354,
#  'writing': 355,
#  'guys': 356,
#  'quality': 357,
#  'close': 358,
#  'art': 359,
#  'wants': 360,
#  'game': 361,
#  'behind': 362,
#  'town': 363,
#  'works': 364,
#  'side': 365,
#  'tries': 366,
#  'days': 367,
#  'past': 368,
#  'viewer': 369,
#  'able': 370,
#  'flick': 371,
#  'hand': 372,
#  'genre': 373,
#  'turns': 374,
#  'act': 375,
#  'enjoyed': 376,
#  'today': 377,
#  'kill': 378,
#  'favorite': 379,
#  'car': 380,
#  'soon': 381,
#  'starts': 382,
#  'actress': 383,
#  'run': 384,
#  'sometimes': 385,
#  'gave': 386,
#  'eyes': 387,
#  'etc': 388,
#  'girls': 389,
#  'late': 390,
#  'god': 391,
#  'directed': 392,
#  'horrible': 393,
#  'kid': 394,
#  'brilliant': 395,
#  'city': 396,
#  'parts': 397,
#  'hour': 398,
#  'blood': 399,
#  'self': 400,
#  'thinking': 401,
#  'stories': 402,
#  'expect': 403,
#  'stuff': 404,
#  'obviously': 405,
#  'decent': 406,
#  'voice': 407,
#  'writer': 408,
#  'fight': 409,
#  'highly': 410,
#  'feeling': 411,
#  'daughter': 412,
#  'slow': 413,
#  'except': 414,
#  'matter': 415,
#  'type': 416,
#  'age': 417,
#  'anyway': 418,
#  'moment': 419,
#  'roles': 420,
#  'heard': 421,
#  'killed': 422,
#  'says': 423,
#  'brother': 424,
#  'leave': 425,
#  'took': 426,
#  'police': 427,
#  'strong': 428,
#  'cannot': 429,
#  'violence': 430,
#  'hit': 431,
#  'stop': 432,
#  'happens': 433,
#  'known': 434,
#  'particularly': 435,
#  'happened': 436,
#  'involved': 437,
#  'extremely': 438,
#  'james': 439,
#  'chance': 440,
#  'obvious': 441,
#  'murder': 442,
#  'living': 443,
#  'told': 444,
#  'coming': 445,
#  'alone': 446,
#  'experience': 447,
#  'lack': 448,
#  'hero': 449,
#  'including': 450,
#  'attempt': 451,
#  'please': 452,
#  'happen': 453,
#  'crap': 454,
#  'gore': 455,
#  'wonder': 456,
#  'complete': 457,
#  'cut': 458,
#  'group': 459,
#  'interest': 460,
#  'ago': 461,
#  'none': 462,
#  'score': 463,
#  'husband': 464,
#  'hell': 465,
#  'david': 466,
#  'save': 467,
#  'simple': 468,
#  'ok': 469,
#  'looked': 470,
#  'song': 471,
#  'career': 472,
#  'number': 473,
#  'seriously': 474,
#  'king': 475,
#  'possible': 476,
#  'annoying': 477,
#  'sad': 478,
#  'exactly': 479,
#  'shown': 480,
#  'running': 481,
#  'musical': 482,
#  'serious': 483,
#  'scary': 484,
#  'reality': 485,
#  'released': 486,
#  'taken': 487,
#  'whose': 488,
#  'english': 489,
#  'ends': 490,
#  'cinematography': 491,
#  'hours': 492,
#  'usually': 493,
#  'opening': 494,
#  'jokes': 495,
#  'light': 496,
#  'hilarious': 497,
#  'body': 498,
#  'cool': 499,
#  'across': 500,
#  'relationship': 501,
#  'somewhat': 502,
#  'usual': 503,
#  'happy': 504,
#  'ridiculous': 505,
#  'started': 506,
#  'level': 507,
#  'view': 508,
#  'change': 509,
#  'opinion': 510,
#  'novel': 511,
#  'wish': 512,
#  'middle': 513,
#  'taking': 514,
#  'talking': 515,
#  'documentary': 516,
#  'ones': 517,
#  'robert': 518,
#  'order': 519,
#  'finds': 520,
#  'power': 521,
#  'shots': 522,
#  'saying': 523,
#  'room': 524,
#  'female': 525,
#  'huge': 526,
#  'mostly': 527,
#  'episodes': 528,
#  'country': 529,
#  'five': 530,
#  'talent': 531,
#  'important': 532,
#  'modern': 533,
#  'earth': 534,
#  'rating': 535,
#  'major': 536,
#  'strange': 537,
#  'word': 538,
#  'turned': 539,
#  'jack': 540,
#  'call': 541,
#  'single': 542,
#  'apparently': 543,
#  'disappointed': 544,
#  'four': 545,
#  'events': 546,
#  'due': 547,
#  'songs': 548,
#  'attention': 549,
#  'basically': 550,
#  'television': 551,
#  'comic': 552,
#  'knows': 553,
#  'future': 554,
#  'clearly': 555,
#  'supporting': 556,
#  'british': 557,
#  'non': 558,
#  'paul': 559,
#  'knew': 560,
#  'fast': 561,
#  'thriller': 562,
#  'class': 563,
#  'easily': 564,
#  'cheap': 565,
#  'silly': 566,
#  'problems': 567,
#  'words': 568,
#  'miss': 569,
#  'tells': 570,
#  'entertainment': 571,
#  'local': 572,
#  'rock': 573,
#  'sequence': 574,
#  'bring': 575,
#  'beyond': 576,
#  'straight': 577,
#  'george': 578,
#  'oscar': 579,
#  'upon': 580,
#  'whether': 581,
#  'predictable': 582,
#  'moving': 583,
#  'romantic': 584,
#  'sets': 585,
#  'similar': 586,
#  'falls': 587,
#  'mystery': 588,
#  'review': 589,
#  'eye': 590,
#  'lady': 591,
#  'richard': 592,
#  'talk': 593,
#  'enjoyable': 594,
#  'appears': 595,
#  'needs': 596,
#  'clich': 597,
#  'giving': 598,
#  'within': 599,
#  'message': 600,
#  'ten': 601,
#  'theater': 602,
#  'animation': 603,
#  'near': 604,
#  'team': 605,
#  'red': 606,
#  'sister': 607,
#  'sequel': 608,
#  'theme': 609,
#  'dull': 610,
#  'nearly': 611,
#  'stand': 612,
#  'points': 613,
#  'lee': 614,
#  'bunch': 615,
#  'mention': 616,
#  'feels': 617,
#  'add': 618,
#  'york': 619,
#  'release': 620,
#  'ways': 621,
#  'storyline': 622,
#  'easy': 623,
#  'using': 624,
#  'surprised': 625,
#  'e': 626,
#  'lots': 627,
#  'named': 628,
#  'fantastic': 629,
#  'begins': 630,
#  'working': 631,
#  'die': 632,
#  'actual': 633,
#  'effort': 634,
#  'feature': 635,
#  'tale': 636,
#  'hate': 637,
#  'french': 638,
#  'minute': 639,
#  'stay': 640,
#  'clear': 641,
#  'tom': 642,
#  'viewers': 643,
#  'follow': 644,
#  'elements': 645,
#  'among': 646,
#  'comments': 647,
#  'typical': 648,
#  'avoid': 649,
#  'showing': 650,
#  'editing': 651,
#  'tried': 652,
#  'season': 653,
#  'famous': 654,
#  'sorry': 655,
#  'peter': 656,
#  'fall': 657,
#  'dialog': 658,
#  'period': 659,
#  'form': 660,
#  'general': 661,
#  'certain': 662,
#  'soundtrack': 663,
#  'filmed': 664,
#  'buy': 665,
#  'parents': 666,
#  'check': 667,
#  'means': 668,
#  'weak': 669,
#  'material': 670,
#  'figure': 671,
#  'realistic': 672,
#  'doubt': 673,
#  'somehow': 674,
#  'crime': 675,
#  'space': 676,
#  'gone': 677,
#  'disney': 678,
#  'leads': 679,
#  'kept': 680,
#  'viewing': 681,
#  'greatest': 682,
#  'th': 683,
#  'dance': 684,
#  'lame': 685,
#  'zombie': 686,
#  'third': 687,
#  'suspense': 688,
#  'imagine': 689,
#  'brought': 690,
#  'atmosphere': 691,
#  'hear': 692,
#  'whatever': 693,
#  'particular': 694,
#  'de': 695,
#  'sequences': 696,
#  'america': 697,
#  'move': 698,
#  'indeed': 699,
#  'average': 700,
#  'eventually': 701,
#  'learn': 702,
#  'rent': 703,
#  'note': 704,
#  'wait': 705,
#  'deal': 706,
#  'reviews': 707,
#  'forget': 708,
#  'surprise': 709,
#  'japanese': 710,
#  'stage': 711,
#  'poorly': 712,
#  'premise': 713,
#  'nature': 714,
#  'believable': 715,
#  'sexual': 716,
#  'subject': 717,
#  'sit': 718,
#  'possibly': 719,
#  'okay': 720,
#  'decided': 721,
#  'expected': 722,
#  'imdb': 723,
#  'dr': 724,
#  'truth': 725,
#  'street': 726,
#  'free': 727,
#  'became': 728,
#  'difficult': 729,
#  'screenplay': 730,
#  'romance': 731,
#  'killing': 732,
#  'baby': 733,
#  'joe': 734,
#  'hot': 735,
#  'dog': 736,
#  'reading': 737,
#  'question': 738,
#  'needed': 739,
#  'leaves': 740,
#  'begin': 741,
#  'meets': 742,
#  'unless': 743,
#  'directors': 744,
#  'credits': 745,
#  'society': 746,
#  'superb': 747,
#  'shame': 748,
#  'otherwise': 749,
#  'write': 750,
#  'situation': 751,
#  'meet': 752,
#  'dramatic': 753,
#  'memorable': 754,
#  'male': 755,
#  'open': 756,
#  'dream': 757,
#  'weird': 758,
#  'badly': 759,
#  'earlier': 760,
#  'writers': 761,
#  'fi': 762,
#  'forced': 763,
#  'laughs': 764,
#  'sci': 765,
#  'acted': 766,
#  'emotional': 767,
#  'crazy': 768,
#  'jane': 769,
#  'older': 770,
#  'beauty': 771,
#  'monster': 772,
#  'realize': 773,
#  'comment': 774,
#  'deep': 775,
#  'footage': 776,
#  'forward': 777,
#  'interested': 778,
#  'fantasy': 779,
#  'ask': 780,
#  'sounds': 781,
#  'plus': 782,
#  'mark': 783,
#  'directing': 784,
#  'features': 785,
#  'keeps': 786,
#  'development': 787,
#  'mess': 788,
#  'quickly': 789,
#  'air': 790,
#  'c': 791,
#  'creepy': 792,
#  'towards': 793,
#  'box': 794,
#  'perfectly': 795,
#  'girlfriend': 796,
#  'worked': 797,
#  'cheesy': 798,
#  'setting': 799,
#  'unique': 800,
#  'bill': 801,
#  'effect': 802,
#  'fire': 803,
#  'plenty': 804,
#  'result': 805,
#  'hands': 806,
#  'total': 807,
#  'previous': 808,
#  'brings': 809,
#  'personal': 810,
#  'rate': 811,
#  'incredibly': 812,
#  'doctor': 813,
#  'return': 814,
#  'business': 815,
#  'christmas': 816,
#  'joke': 817,
#  'apart': 818,
#  'leading': 819,
#  'casting': 820,
#  'admit': 821,
#  'powerful': 822,
#  'cop': 823,
#  'appear': 824,
#  'background': 825,
#  'boys': 826,
#  'ben': 827,
#  'present': 828,
#  'era': 829,
#  'battle': 830,
#  'meant': 831,
#  'hardly': 832,
#  'telling': 833,
#  'potential': 834,
#  'masterpiece': 835,
#  'create': 836,
#  'secret': 837,
#  'break': 838,
#  'pay': 839,
#  'gay': 840,
#  'dumb': 841,
#  'political': 842,
#  'fighting': 843,
#  'twist': 844,
#  'fails': 845,
#  'co': 846,
#  'various': 847,
#  'portrayed': 848,
#  'inside': 849,
#  'western': 850,
#  'villain': 851,
#  'nudity': 852,
#  'reasons': 853,
#  'william': 854,
#  'outside': 855,
#  'ideas': 856,
#  'front': 857,
#  'missing': 858,
#  'deserves': 859,
#  'married': 860,
#  'match': 861,
#  'expecting': 862,
#  'rich': 863,
#  'fairly': 864,
#  'talented': 865,
#  'success': 866,
#  'list': 867,
#  'unlike': 868,
#  'scott': 869,
#  'remake': 870,
#  'manages': 871,
#  'attempts': 872,
#  'odd': 873,
#  'social': 874,
#  'cute': 875,
#  'recently': 876,
#  'flat': 877,
#  'sadly': 878,
#  'copy': 879,
#  'wrote': 880,
#  'agree': 881,
#  'sweet': 882,
#  'cold': 883,
#  'crew': 884,
#  'spoilers': 885,
#  'plain': 886,
#  'mary': 887,
#  'office': 888,
#  'filmmakers': 889,
#  'missed': 890,
#  'following': 891,
#  'mentioned': 892,
#  'public': 893,
#  'gun': 894,
#  'incredible': 895,
#  'pure': 896,
#  'wasted': 897,
#  'brothers': 898,
#  'large': 899,
#  'ended': 900,
#  'caught': 901,
#  'revenge': 902,
#  'produced': 903,
#  'la': 904,
#  'members': 905,
#  'filled': 906,
#  'pace': 907,
#  'popular': 908,
#  'party': 909,
#  'science': 910,
#  'waiting': 911,
#  'water': 912,
#  'cat': 913,
#  'decides': 914,
#  'considering': 915,
#  'cartoon': 916,
#  'hold': 917,
#  'spirit': 918,
#  'created': 919,
#  'slightly': 920,
#  'tension': 921,
#  'uses': 922,
#  'convincing': 923,
#  'escape': 924,
#  'fear': 925,
#  'suddenly': 926,
#  'compared': 927,
#  'familiar': 928,
#  'neither': 929,
#  'sees': 930,
#  'spent': 931,
#  'island': 932,
#  'cause': 933,
#  'intelligent': 934,
#  'state': 935,
#  'clever': 936,
#  'f': 937,
#  'entirely': 938,
#  'credit': 939,
#  'moves': 940,
#  'kills': 941,
#  'bored': 942,
#  'band': 943,
#  'dancing': 944,
#  'language': 945,
#  'century': 946,
#  'laughing': 947,
#  'choice': 948,
#  'italian': 949,
#  'cover': 950,
#  'successful': 951,
#  'value': 952,
#  'violent': 953,
#  'visual': 954,
#  'trouble': 955,
#  'speak': 956,
#  'tony': 957,
#  'ultimately': 958,
#  'concept': 959,
#  'singing': 960,
#  'store': 961,
#  'basic': 962,
#  'zombies': 963,
#  'positive': 964,
#  'studio': 965,
#  'german': 966,
#  'animated': 967,
#  'exciting': 968,
#  'company': 969,
#  'biggest': 970,
#  'force': 971,
#  'consider': 972,
#  'runs': 973,
#  'died': 974,
#  'effective': 975,
#  'walk': 976,
#  'depth': 977,
#  'adventure': 978,
#  'control': 979,
#  'law': 980,
#  'recent': 981,
#  'adult': 982,
#  'amusing': 983,
#  'former': 984,
#  'focus': 985,
#  'common': 986,
#  'spend': 987,
#  'portrayal': 988,
#  'rated': 989,
#  'appreciate': 990,
#  'hair': 991,
#  'books': 992,
#  'pointless': 993,
#  'trash': 994,
#  'younger': 995,
#  'solid': 996,
#  'planet': 997,
#  'impressive': 998,
#  'super': 999,
#  'tone': 1000,
#  ...}

# %%
print('len(x_train_tokenized):', len(x_train_tokenized))
x_train_tokenized
# Out:
# len(x_train_tokenized): 25000
# [[404,
#   70,
#   419,
#   506,
#   2456,
#   115,
#   54,
#   873,
#   516,
#   178,
#   178,
#   165,
#   78,
#   14,
#   662,
#   2457,
#   117,
#   92,
#   10,
#   499,
#   4074,
#   165,
#   22,
#   210,
#   581,
#   2333,
#   1194,
#   71,
#   4826,
#   71,
#   635,
#   2,
#   253,
#   70,
#   11,
#   302,
#   1663,
#   486,
#   1144,
#   3265,
#   411,
#   793,
#   3342,
#   17,
#   441,
#   600,
#   1500,
#   15,
#   4424,
#   1851,
#   998,
#   146,
#   342,
#   1442,
#   743,
#   2424,
#   4,
#   418,
#   70,
#   637,
#   69,
#   237,
#   94,
#   541,
#   120,
#   1,
#   323,
#   8,
#   47,
#   20,
#   323,
#   167,
#   10,
#   207,
#   633,
#   635,
#   2,
#   116,
#   291,
#   382,
#   121,
#   3315,
#   1501,
#   574,
#   734,
#   923,
#   822,
#   1239,
#   1408,
#   360,
#   221,
#   15,
#   576,
#   2274,
#   734,
#   27,
#   340,
#   16,
#   41,
#   1500,
#   388,
#   165,
#   3962,
#   115,
#   627,
#   499,
#   79,
#   4,
#   1430,
#   380,
#   2163,
#   114,
#   1919,
#   2503,
#   574,
#   17,
#   60,
#   100,
#   4875,
#   5100,
#   260,
#   1268,
#   15,
#   574,
#   493,
#   744,
#   637,
#   631,
#   3,
#   394,
#   164,
#   446,
#   114,
#   615,
#   3266,
#   1160,
#   684,
#   48,
#   1175,
#   224,
#   1,
#   16,
#   4,
#   3,
#   507,
#   62,
#   25,
#   16,
#   640,
#   133,
#   231,
#   95,
#   600,
#   3439,
#   1864,
#   1,
#   128,
#   342,
#   1442,
#   247,
#   3,
#   865,
#   16,
#   42,
#   1487,
#   997,
#   2333,
#   12,
#   549,
#   386,
#   717,
#   12,
#   41,
#   16,
#   158,
#   362,
#   4392,
#   3388,
#   41,
#   87,
#   225,
#   438,
#   207,
#   254,
#   117,
#   3,
#   316,
#   1356],
#  [232,
#   203,
#   3048,
#   3565,
#   317,
#   2,
#   405,
#   153,
#   19,
#   634,
#   1653,
#   1035,
#   3494,
#   232,
#   154,
#   314,
#   2701,
#   178,
#   2,
#   2349,
#   87,
#   1111,
#   582,
#   217,
#   2219,
#   149,
#   73,
#   160,
#   626,
#   1035,
#   2882,
#   194,
#   642,
#   3316,
#   3464,
#   3869,
#   154,
#   405,
#   180,
#   155,
#   158,
#   79,
#   1,
#   2177,
#   1251,
#   68,
#   170,
#   281,
#   811,
#   1,
#   532,
#   4,
#   2003,
#   16,
#   36,
#   881,
#   1251,
#   376,
#   634,
#   314,
#   159,
#   2564,
#   1653,
#   1035,
#   3494,
#   232,
#   511,
#   143,
#   317,
#   20,
#   623,
#   4628,
#   1251,
#   5471],
#  [2,
#   382,
#   2818,
#   4393,
#   3730,
#   598,
#   2184,
#   518,
#   4313,
#   1328,
#   837,
#   1012,
#   1435,
#   624,
#   4,
#   1328,
#   3102,
#   3,
#   714,
#   4592,
#   3542,
#   5590,
#   374,
#   2305,
#   86,
#   193,
#   2869,
#   1443,
#   924,
#   630,
#   4954,
#   279,
#   3542,
#   1920,
#   2350,
#   1454,
#   2366,
#   2046,
#   2827,
#   2911,
#   899,
#   1569,
#   1217,
#   1208,
#   1791,
#   1416,
#   2366,
#   1362,
#   3465,
#   1396,
#   409,
#   832,
#   146,
#   53,
#   201,
#   256,
#   55,
#   923,
#   1301,
#   1208,
#   4954,
#   459,
#   384,
#   409,
#   3,
#   714,
#   3900,
#   687,
#   1656,
#   413,
#   1308,
#   1,
#   1382,
#   627,
#   399,
#   455,
#   991,
#   4314,
#   5218,
#   244,
#   2425,
#   824,
#   1350,
#   198,
#   183,
#   9,
#   1403,
#   968,
#   571,
#   1750,
#   77,
#   237,
#   1301,
#   1208,
#   1999,
#   20,
#   1064,
#   191,
#   354,
#   2143,
#   233,
#   55,
#   1684,
#   5048,
#   1409,
#   1472,
#   59,
#   95,
#   1578,
#   233,
#   481,
#   2552,
#   3227,
#   505,
#   344,
#   2305,
#   48,
#   266,
#   229,
#   672,
#   2030,
#   953,
#   1109,
#   49,
#   30,
#   891,
#   439,
#   1078,
#   5591,
#   2064,
#   466,
#   4556,
#   182,
#   3300,
#   13,
#   44,
#   1975,
#   3731,
#   3072,
#   1110,
#   304,
#   906,
#   1602,
#   262,
#   759,
#   392,
#   578,
#   2674,
#   2656,
#   187,
#   32,
#   645,
#   808,
#   30,
#   2674,
#   2251,
#   60,
#   493,
#   631,
#   551,
#   2635,
#   1123,
#   2046,
#   534,
#   32,
#   281,
#   1875,
#   302,
#   43,
#   1671,
#   4356,
#   535,
#   700,
#   1175,
#   5310],
#  [100,
#   4827,
#   5311,
#   2,
#   682,
#   664,
#   1258,
#   42,
#   212,
#   1036,
#   225,
#   328,
#   1258,
#   328,
#   5049,
#   328,
#   123,
#   414,
#   1592,
#   824,
#   225,
#   5472,
#   5049,
#   471,
#   1,
#   3197,
#   1524,
#   737,
#   463,
#   4509,
#   2828,
#   4425,
#   16,
#   856,
#   1258,
#   415,
#   177,
#   145,
#   3,
#   1636,
#   1502,
#   1593,
#   604,
#   1529,
#   2,
#   965,
#   99,
#   5049,
#   2828,
#   721,
#   300,
#   27,
#   1356,
#   5353,
#   131,
#   4105,
#   55,
#   3,
#   1838,
#   1781,
#   193,
#   59,
#   2,
#   4955,
#   14,
#   1246,
#   5159,
#   5592,
#   31,
#   267,
#   421,
#   407,
#   17,
#   595,
#   1246,
#   4828,
#   131,
#   270,
#   5,
#   2334,
#   115,
#   21,
#   714,
#   4132,
#   1404,
#   1664,
#   2806,
#   1529,
#   385,
#   292,
#   2149,
#   25,
#   2351,
#   5259,
#   2243,
#   2622,
#   2933,
#   347,
#   115,
#   347,
#   140,
#   4133,
#   193,
#   2155,
#   694,
#   1455,
#   62,
#   305,
#   3440,
#   166,
#   62,
#   589,
#   892,
#   4669,
#   55,
#   275,
#   413,
#   5592,
#   3732,
#   1351,
#   168,
#   411,
#   2788,
#   115,
#   200,
#   946,
#   347,
#   152,
#   533,
#   46,
#   1561,
#   2],
#  [3364,
#   4134,
#   2037,
#   1569,
#   745,
#   494,
#   696,
#   502,
#   95,
#   2372,
#   1228,
#   1794,
#   483,
#   325,
#   238,
#   925,
#   1037,
#   601,
#   121,
#   184,
#   4829,
#   5260,
#   3180,
#   2471,
#   5312,
#   1689,
#   3073,
#   2004,
#   852,
#   2860,
#   5908,
#   29,
#   358,
#   7,
#   920,
#   501,
#   689,
#   5758,
#   3198,
#   607,
#   1133,
#   498,
#   5828,
#   324,
#   114,
#   121,
#   12,
#   2860,
#   607,
#   4038,
#   2113,
#   1958,
#   210,
#   1026,
#   2504,
#   418,
#   229,
#   4956,
#   666,
#   1436,
#   1171,
#   4463,
#   3870,
#   2373,
#   426,
#   86,
#   7,
#   2668,
#   4210,
#   2860,
#   5908,
#   2588,
#   633,
#   34,
#   58,
#   184,
#   4244,
#   1928,
#   2505,
#   812,
#   4357,
#   301,
#   803,
#   3389,
#   143,
#   1739,
#   79,
#   33,
#   42,
#   20,
#   38,
#   168,
#   34,
#   1165,
#   2252,
#   301,
#   803,
#   139,
#   72,
#   138,
#   28,
#   6,
#   2114,
#   3144,
#   933,
#   1959,
#   59,
#   2553,
#   7,
#   208,
#   693,
#   430,
#   5050,
#   73,
#   542,
#   34,
#   844,
#   2789,
#   118,
#   153,
#   354,
#   576,
#   926,
#   2426,
#   169,
#   2860,
#   596,
#   5908,
#   1599,
#   3267,
#   48,
#   89,
#   1474,
#   2742,
#   206,
#   5051,
#   572,
#   2860,
#   3963,
#   949,
#   2038,
#   89,
#   3317,
#   3999,
#   1029,
#   5160,
#   4426,
#   609,
#   471,
#   181,
#   112,
#   2352,
#   103,
#   337,
#   2,
#   5420,
#   1293,
#   37,
#   4000,
#   4106,
#   391,
#   395,
#   447,
#   96,
#   638,
#   300,
#   33,
#   1843,
#   2134,
#   67,
#   13,
#   168,
#   239,
#   1,
#   462],
#  [5219,
#   41,
#   16,
#   25,
#   15,
#   1,
#   85,
#   80,
#   5,
#   34,
#   5,
#   97,
#   509,
#   1456,
#   1083,
#   1295,
#   225,
#   139,
#   2211,
#   2004,
#   1,
#   4,
#   3145,
#   5,
#   660,
#   1469,
#   1083,
#   297,
#   3074,
#   1,
#   266,
#   363,
#   823,
#   297,
#   1469,
#   1083,
#   11,
#   3,
#   72,
#   44,
#   221,
#   2898],
#  [1,
#   23,
#   5,
#   149,
#   21,
#   226,
#   798,
#   198,
#   183,
#   35,
#   23,
#   470,
#   368,
#   9,
#   2143,
#   825,
#   9,
#   8,
#   44,
#   34,
#   4427,
#   83,
#   315,
#   1516,
#   130,
#   105,
#   1,
#   3284,
#   36,
#   555,
#   2374,
#   123,
#   786,
#   1197,
#   3075,
#   71,
#   220,
#   4075,
#   1,
#   1,
#   834,
#   155,
#   4,
#   10,
#   15,
#   20,
#   132,
#   1,
#   8,
#   649,
#   1],
#  [178,
#   248,
#   318,
#   189,
#   1108,
#   310,
#   161,
#   2493,
#   3,
#   248,
#   950,
#   48,
#   1,
#   3,
#   1,
#   382,
#   324,
#   2769,
#   4039,
#   2291,
#   1804,
#   2292,
#   2574,
#   3210,
#   894,
#   226,
#   248,
#   4771,
#   5829,
#   248,
#   3673,
#   407,
#   188,
#   3005,
#   76,
#   1476,
#   884,
#   47,
#   248,
#   490,
#   650,
#   2,
#   2265,
#   201,
#   1223,
#   281,
#   352,
#   147,
#   438,
#   4245,
#   305,
#   179,
#   661,
#   910,
#   15,
#   248],
#  [318,
#   1739,
#   1089,
#   2,
#   7,
#   335,
#   1728,
#   89,
#   1275,
#   1603,
#   2623,
#   1316,
#   1805,
#   812,
#   865,
#   2702,
#   81,
#   2,
#   65,
#   514,
#   577,
#   922,
#   1298,
#   1175,
#   5310,
#   1547,
#   3181,
#   3964,
#   2055,
#   2589,
#   1336,
#   2623,
#   2144,
#   185,
#   1417,
#   993,
#   735,
#   389,
#   1603,
#   2623,
#   181,
#   3316,
#   1418,
#   360,
#   22,
#   951,
#   2819,
#   519,
#   288,
#   951,
#   235,
#   1418,
#   4670,
#   2819,
#   628,
#   547,
#   866,
#   1806,
#   4464,
#   285,
#   1818,
#   2623,
#   27,
#   105,
#   89,
#   838,
#   221,
#   136,
#   2703,
#   3674,
#   3343,
#   1818,
#   1026,
#   259,
#   1474,
#   137,
#   2,
#   6],
#  [1,
#   244,
#   1921,
#   4,
#   1001,
#   2178,
#   1343,
#   1149,
#   3,
#   32,
#   281,
#   267,
#   641,
#   2718,
#   3146,
#   656,
#   1,
#   835,
#   593,
#   13,
#   554],
#  [433,
#   1094,
#   4772,
#   1694,
#   5005,
#   1766,
#   1058,
#   3409,
#   1767,
#   3228,
#   146,
#   62,
#   1172,
#   333,
#   829,
#   2494,
#   406,
#   556,
#   75,
#   2675,
#   1156,
#   3621,
#   1224],
#  [144,
#   1065,
#   4,
#   5052,
#   3163,
#   5052,
#   310,
#   6,
#   2,
#   1243,
#   66,
#   41,
#   119,
#   737,
#   808,
#   774,
#   870,
#   510,
#   2676,
#   633,
#   2,
#   1903,
#   9,
#   21,
#   272,
#   738,
#   5830,
#   238,
#   568,
#   177,
#   1822,
#   1812,
#   3076,
#   747,
#   31,
#   24,
#   3,
#   662,
#   5,
#   59,
#   294,
#   1812,
#   102,
#   3365,
#   607,
#   473,
#   654,
#   201,
#   424,
#   6,
#   2668,
#   87,
#   738,
#   177,
#   12,
#   177,
#   314,
#   555,
#   227,
#   5703,
#   261,
#   2,
#   227,
#   30,
#   11,
#   276,
#   163],
#  [314,
#   3871,
#   2527,
#   395,
#   127,
#   3565,
#   5473,
#   2516,
#   1552,
#   305,
#   838,
#   321,
#   775,
#   837,
#   368,
#   1280,
#   1604,
#   2031,
#   1261,
#   77,
#   583,
#   493,
#   105,
#   1819,
#   71,
#   1709,
#   5101,
#   722,
#   237,
#   263,
#   2472,
#   1013,
#   222,
#   552,
#   4722,
#   1203,
#   751,
#   1830,
#   118,
#   12,
#   3701,
#   753,
#   4722,
#   110,
#   1266,
#   1557,
#   2427,
#   557,
#   2031,
#   229,
#   251,
#   1782,
#   893,
#   263,
#   5005,
#   206,
#   229,
#   483,
#   1058,
#   301,
#   257,
#   389,
#   77,
#   1795,
#   81,
#   59,
#   3702,
#   557,
#   132,
#   503,
#   2031,
#   4428,
#   193,
#   874,
#   1299,
#   4629,
#   108,
#   493,
#   177,
#   838,
#   1013,
#   679,
#   2912,
#   281,
#   2228,
#   25,
#   4,
#   1552,
#   848,
#   827,
#   1844,
#   4830,
#   1876,
#   1564,
#   13,
#   1631,
#   16,
#   12,
#   391,
#   2428,
#   1022,
#   1586,
#   6,
#   2428,
#   697,
#   1022,
#   1027,
#   816,
#   3342,
#   17,
#   5,
#   1318,
#   37,
#   1163,
#   108,
#   314,
#   3871,
#   3049,
#   23,
#   142,
#   1,
#   1084,
#   1142,
#   1942,
#   1910,
#   21,
#   341,
#   109,
#   1431,
#   48,
#   3622,
#   116,
#   1014,
#   2528,
#   324,
#   103,
#   2590,
#   1143,
#   1013,
#   1695,
#   2,
#   39,
#   5,
#   793,
#   215,
#   31,
#   2975,
#   132,
#   24],
#  [411,
#   3,
#   44,
#   98,
#   100,
#   150,
#   161,
#   328,
#   344,
#   2047,
#   407,
#   105,
#   3543,
#   2113,
#   2870,
#   781,
#   64,
#   4,
#   651,
#   12,
#   1079,
#   2169,
#   64,
#   348,
#   791,
#   1079,
#   1,
#   90,
#   161,
#   3285,
#   250,
#   865,
#   469,
#   347,
#   5102,
#   4,
#   808,
#   3526,
#   186,
#   567,
#   191,
#   824,
#   1038,
#   242,
#   407,
#   2899,
#   388,
#   15,
#   933,
#   34,
#   66,
#   469,
#   5909,
#   371,
#   36,
#   703,
#   62,
#   5909,
#   371,
#   743,
#   2080,
#   15,
#   569,
#   1158],
#  [704,
#   578,
#   281,
#   588,
#   910,
#   602,
#   25,
#   379,
#   150,
#   4,
#   211,
#   457,
#   5103,
#   98,
#   12,
#   8,
#   47,
#   100,
#   95,
#   939,
#   2544,
#   1169,
#   884,
#   151,
#   132,
#   1,
#   10,
#   22,
#   13,
#   138,
#   658,
#   801,
#   5,
#   372,
#   242,
#   15,
#   7,
#   8,
#   4428,
#   193,
#   263,
#   325,
#   1145,
#   23,
#   44,
#   8,
#   261,
#   665,
#   154,
#   212,
#   3017],
#  [1492,
#   475,
#   1098,
#   3566,
#   475,
#   81,
#   106,
#   3784,
#   69,
#   2719,
#   5831,
#   358,
#   223,
#   197,
#   520,
#   1393,
#   576,
#   2719,
#   5831,
#   1541,
#   146,
#   123,
#   3366,
#   149,
#   52,
#   77,
#   98,
#   700,
#   84,
#   304,
#   382,
#   3935,
#   3318,
#   2602,
#   1838,
#   21,
#   1397,
#   137,
#   1273,
#   3367,
#   127,
#   105,
#   38,
#   44,
#   1690,
#   45,
#   1904,
#   1031,
#   1796,
#   104,
#   87,
#   114,
#   1,
#   10,
#   1031,
#   220,
#   112,
#   51,
#   22,
#   754,
#   406,
#   556,
#   233,
#   1599,
#   1372,
#   57,
#   2039,
#   3122,
#   2603,
#   918,
#   2013,
#   90,
#   10,
#   5474,
#   2,
#   475,
#   503,
#   1852,
#   5261,
#   1320,
#   608,
#   17,
#   392,
#   887,
#   456,
#   2293,
#   2,
#   61,
#   126],
#  [2342,
#   968,
#   1318,
#   2458,
#   1851,
#   629,
#   17,
#   92,
#   2720,
#   4510,
#   2992,
#   5053,
#   1209,
#   661,
#   2437,
#   608,
#   861,
#   5759,
#   306,
#   7,
#   1503,
#   1488,
#   148,
#   2409,
#   1464,
#   1440,
#   494,
#   1410,
#   18,
#   1228,
#   1065,
#   5,
#   3,
#   204,
#   757,
#   1080,
#   2,
#   3006,
#   5760,
#   18,
#   121,
#   3567,
#   2350,
#   2342,
#   1362,
#   1010,
#   830,
#   187,
#   156,
#   1823,
#   1919,
#   4040,
#   639,
#   380,
#   1132,
#   574,
#   105,
#   7,
#   306,
#   89,
#   1357,
#   844,
#   45,
#   137,
#   5354,
#   4831,
#   48,
#   303,
#   64,
#   34,
#   17,
#   1066,
#   1182,
#   1344,
#   684,
#   115,
#   3803,
#   6,
#   1095,
#   2342,
#   5,
#   1416,
#   22,
#   191,
#   237,
#   18,
#   3,
#   111,
#   34,
#   374,
#   5910,
#   2424,
#   111,
#   1,
#   550,
#   93,
#   2829,
#   3441,
#   76,
#   1751,
#   10,
#   364,
#   1791,
#   44,
#   595,
#   2342,
#   2883,
#   789,
#   198,
#   183,
#   201,
#   1475,
#   4076,
#   35,
#   1111,
#   218,
#   71,
#   39,
#   27,
#   146,
#   153,
#   1362,
#   1010,
#   3,
#   920,
#   111,
#   5355,
#   3733,
#   198,
#   183,
#   38,
#   524,
#   22,
#   13,
#   1319,
#   1632,
#   1183,
#   5161,
#   5704,
#   3568,
#   218,
#   289,
#   3593,
#   1678,
#   71,
#   97,
#   2038,
#   23,
#   113,
#   13,
#   44,
#   383,
#   218,
#   1214,
#   176,
#   1,
#   2342,
#   1233,
#   4,
#   18,
#   3,
#   2212,
#   3,
#   632,
#   140,
#   323,
#   7,
#   1,
#   1329,
#   373,
#   198,
#   802,
#   5642,
#   4246,
#   2342,
#   388,
#   46,
#   136,
#   218,
#   723,
#   535],
#  [2,
#   43,
#   232,
#   700,
#   241,
#   230,
#   173,
#   68,
#   608,
#   43,
#   1343,
#   958,
#   310,
#   6,
#   112,
#   317,
#   3,
#   487,
#   112,
#   116,
#   474,
#   1343,
#   196,
#   1150,
#   756,
#   62,
#   608,
#   3,
#   2770,
#   199,
#   112,
#   3,
#   3,
#   135,
#   55,
#   3182,
#   961,
#   4358,
#   260,
#   500,
#   2,
#   5421,
#   814,
#   43,
#   143,
#   608,
#   760,
#   30,
#   504,
#   5832,
#   3410,
#   434,
#   44,
#   55,
#   494,
#   300,
#   43,
#   608,
#   29,
#   119,
#   1561,
#   30,
#   628,
#   12,
#   354,
#   418,
#   2495,
#   332,
#   123,
#   5,
#   164,
#   11,
#   776,
#   43,
#   226,
#   1081,
#   5980,
#   255,
#   3936,
#   3936,
#   18,
#   1,
#   807,
#   2529,
#   153,
#   3,
#   48,
#   252,
#   99,
#   123,
#   2424,
#   111,
#   484,
#   1294,
#   35,
#   3229,
#   39,
#   59,
#   1173,
#   243,
#   60,
#   35,
#   447,
#   1530,
#   129,
#   462,
#   126,
#   34,
#   118,
#   272,
#   334,
#   886,
#   249,
#   60,
#   366,
#   22,
#   2,
#   68,
#   5313,
#   120,
#   245,
#   698,
#   83,
#   2527,
#   1455,
#   64,
#   115,
#   610,
#   140,
#   692,
#   397,
#   3965,
#   96,
#   37,
#   27,
#   628,
#   5705,
#   546,
#   2220,
#   326,
#   96,
#   88,
#   156,
#   17,
#   300,
#   616,
#   436,
#   1343,
#   291,
#   1455,
#   64,
#   63,
#   111,
#   225,
#   93,
#   373,
#   344,
#   2149,
#   16,
#   362,
#   310,
#   6,
#   161,
#   2830,
#   3,
#   56,
#   96,
#   2,
#   60,
#   18,
#   1905,
#   188,
#   298,
#   608,
#   2,
#   835,
#   1383,
#   139,
#   119,
#   111,
#   317,
#   42,
#   62,
#   608,
#   673,
#   596,
#   708,
#   3,
#   42,
#   436,
#   2229,
#   225,
#   166,
#   112,
#   205,
#   22,
#   406,
#   84,
#   2,
#   535],
#  [1,
#   3,
#   646,
#   1229,
#   24,
#   8,
#   36,
#   5262,
#   133,
#   6,
#   8,
#   3164,
#   1112,
#   42,
#   7,
#   1229,
#   302,
#   1544,
#   1007,
#   5643,
#   2081,
#   88,
#   1302,
#   2,
#   548,
#   491,
#   2294,
#   202,
#   1797,
#   302,
#   4211,
#   802,
#   2,
#   677,
#   367,
#   19,
#   302,
#   73,
#   48,
#   32,
#   103,
#   487,
#   549,
#   1375,
#   651,
#   49,
#   2861,
#   49,
#   906,
#   767,
#   2831,
#   4,
#   1672,
#   2884,
#   47,
#   293,
#   1190,
#   1444,
#   1965,
#   481,
#   419,
#   5475,
#   4907,
#   1002,
#   428,
#   1752,
#   4077,
#   133,
#   1488,
#   2807,
#   4907,
#   3230,
#   102,
#   1865,
#   1853,
#   568,
#   1229,
#   302,
#   343,
#   457,
#   1,
#   1701,
#   799,
#   58,
#   1768,
#   1268,
#   5476,
#   548,
#   99,
#   358,
#   1804,
#   591,
#   352,
#   108,
#   1664,
#   843,
#   33,
#   273],
#  [16,
#   145,
#   81,
#   16,
#   94,
#   268,
#   2,
#   155,
#   4,
#   9,
#   1776,
#   66,
#   9,
#   446,
#   16,
#   94,
#   36,
#   122,
#   5104,
#   507,
#   27,
#   2398,
#   807,
#   1806,
#   27,
#   2398,
#   295,
#   2438,
#   151,
#   708,
#   33,
#   1807,
#   265,
#   75,
#   2623,
#   2496,
#   1508,
#   552,
#   108,
#   19,
#   2623,
#   11,
#   3007,
#   1036,
#   346,
#   2,
#   42,
#   285,
#   295,
#   446,
#   2,
#   446,
#   1300],
#  [5981,
#   1234,
#   3,
#   39,
#   1031,
#   910,
#   1051,
#   24,
#   46,
#   7,
#   377,
#   1388,
#   144,
#   2862,
#   38,
#   1798,
#   1059,
#   713,
#   648,
#   6,
#   46,
#   122,
#   4135,
#   92,
#   2720,
#   2,
#   357,
#   507,
#   1999,
#   2213,
#   1380,
#   428,
#   75,
#   1431,
#   696,
#   1116,
#   972,
#   232,
#   63,
#   619,
#   2099,
#   156,
#   1075,
#   3703,
#   807,
#   73,
#   5476,
#   1472,
#   2047,
#   660,
#   1472,
#   1281,
#   5981,
#   969,
#   5644,
#   3183,
#   19,
#   2820,
#   181,
#   823,
#   5356,
#   442,
#   3,
#   5981,
#   5645,
#   580,
#   330,
#   3704,
#   118,
#   38,
#   3008,
#   103,
#   1174,
#   10,
#   107,
#   89,
#   709,
#   46,
#   691,
#   2913,
#   5105,
#   574,
#   247,
#   564,
#   3,
#   5982,
#   262,
#   302,
#   2275,
#   1035,
#   4356,
#   958,
#   998,
#   124,
#   108,
#   19,
#   5911,
#   108,
#   2048,
#   399,
#   724,
#   910,
#   1051,
#   154,
#   3268,
#   5262,
#   1706,
#   3544,
#   676,
#   4957,
#   1729,
#   997],
#  [342,
#   181,
#   1709,
#   3211,
#   3390,
#   2005,
#   111,
#   1345,
#   2006,
#   793,
#   2946,
#   312,
#   1133,
#   3623,
#   235,
#   255,
#   258,
#   215,
#   1823,
#   2082,
#   235,
#   66,
#   258,
#   1425,
#   168,
#   2885,
#   771,
#   217,
#   2914,
#   4359,
#   3569,
#   958,
#   1047,
#   215,
#   221,
#   193,
#   5054,
#   4211,
#   5761,
#   3901,
#   169,
#   1,
#   1854,
#   716,
#   5833,
#   9,
#   149,
#   2552,
#   22,
#   32,
#   2915,
#   755,
#   77,
#   3344,
#   1740,
#   90,
#   49,
#   852,
#   1643,
#   68,
#   4723,
#   5,
#   1489,
#   258,
#   2704,
#   536,
#   5159,
#   146,
#   199,
#   1093,
#   706,
#   4211,
#   1804,
#   2156,
#   5529,
#   793,
#   3,
#   56,
#   1709,
#   387,
#   4359,
#   4211,
#   121,
#   6,
#   291,
#   3495,
#   4723,
#   502,
#   2976,
#   115,
#   663,
#   994,
#   2552,
#   236,
#   3,
#   2276,
#   62,
#   7,
#   1519,
#   3,
#   2266,
#   1709,
#   3838,
#   3966,
#   413,
#   907,
#   983,
#   2771,
#   844,
#   2324,
#   64,
#   209,
#   70,
#   282,
#   276,
#   643,
#   148],
#  [504,
#   50,
#   1831,
#   1082,
#   321,
#   136,
#   3570,
#   754,
#   4671,
#   12,
#   511,
#   1171,
#   172,
#   18,
#   811,
#   571,
#   557,
#   1094,
#   2554,
#   3839,
#   1832,
#   1382,
#   3123,
#   3466,
#   24,
#   159,
#   176,
#   152,
#   2554,
#   1285,
#   5912,
#   172,
#   557,
#   2000,
#   912,
#   5646,
#   4832,
#   1092,
#   1039,
#   3804,
#   3467,
#   320,
#   5834,
#   3839,
#   1832,
#   124,
#   5834,
#   579,
#   2049,
#   2013,
#   4773,
#   5834,
#   1548,
#   1605,
#   3184,
#   3734,
#   140,
#   2604,
#   140,
#   138,
#   1545,
#   5983,
#   488,
#   58,
#   288,
#   343,
#   2274,
#   2100,
#   1606,
#   5314,
#   2350,
#   3185,
#   815,
#   1795,
#   2274,
#   519,
#   52,
#   97,
#   518,
#   3009,
#   1239,
#   429,
#   5006,
#   200,
#   138,
#   54,
#   151,
#   99,
#   60,
#   578,
#   4315,
#   918,
#   978,
#   1579,
#   277,
#   4211,
#   1533,
#   1094,
#   2048,
#   1653,
#   1833,
#   579,
#   4170,
#   1191,
#   206,
#   301,
#   491],
#  [8,
#   37,
#   29,
#   492,
#   33,
#   52,
#   336,
#   324,
#   2769,
#   1040,
#   1435,
#   997,
#   93,
#   3570,
#   4279,
#   118,
#   50,
#   100,
#   11,
#   705,
#   248],
#  [118,
#   1,
#   129,
#   143,
#   991,
#   1665,
#   876,
#   10,
#   57,
#   736,
#   527,
#   2177,
#   2,
#   685,
#   3496,
#   1224,
#   2900,
#   3,
#   314],
#  [150,
#   572,
#   248,
#   961,
#   143,
#   194,
#   470,
#   111,
#   1154,
#   349,
#   13,
#   3442,
#   2237,
#   131,
#   2,
#   2624,
#   1446,
#   146,
#   158,
#   1198,
#   13,
#   315,
#   4724,
#   4212,
#   8,
#   136,
#   5315,
#   472,
#   129,
#   3365,
#   534,
#   159,
#   2555,
#   819,
#   3411,
#   13,
#   138,
#   138,
#   2605,
#   3345,
#   6,
#   108,
#   142,
#   173,
#   293,
#   4394,
#   4316,
#   3,
#   32,
#   3,
#   104,
#   3,
#   3,
#   42,
#   268,
#   211,
#   85,
#   98],
#  [704,
#   1001,
#   3102,
#   2410,
#   70,
#   338,
#   339,
#   772,
#   238,
#   95,
#   274,
#   559,
#   328,
#   2355,
#   3093,
#   2253,
#   2530,
#   1096,
#   16,
#   912,
#   12,
#   2065,
#   1358,
#   95,
#   394,
#   1357,
#   274,
#   4,
#   573,
#   7,
#   5530,
#   129,
#   718,
#   947,
#   2495,
#   14,
#   3624,
#   559,
#   772,
#   5758,
#   137,
#   71,
#   1,
#   3093,
#   56,
#   5220,
#   559,
#   337,
#   309,
#   371,
#   67,
#   23,
#   406,
#   484,
#   84,
#   1,
#   191,
#   566,
#   2556,
#   2089,
#   397,
#   3093,
#   3102,
#   987,
#   309,
#   1,
#   4465,
#   246,
#   932,
#   1929,
#   3,
#   389,
#   382,
#   1124,
#   5259,
#   2399,
#   912,
#   2014,
#   146,
#   1898,
#   559,
#   107,
#   912,
#   378,
#   3,
#   56,
#   1119,
#   98,
#   1,
#   164,
#   286,
#   266,
#   3124,
#   749,
#   1179,
#   1],
#  [100,
#   99,
#   673,
#   970,
#   310,
#   2,
#   2606,
#   245,
#   42,
#   41,
#   152,
#   1235,
#   1015,
#   193,
#   254,
#   167,
#   2,
#   46,
#   122,
#   4041,
#   50,
#   2127,
#   161,
#   52,
#   689,
#   140,
#   4213,
#   953,
#   311,
#   2,
#   4280,
#   12,
#   66,
#   476,
#   328,
#   208,
#   1019,
#   292,
#   1088,
#   139,
#   328,
#   231,
#   836,
#   2185,
#   116,
#   921,
#   60,
#   1492,
#   2790,
#   353,
#   13,
#   3246,
#   69,
#   161,
#   274,
#   4,
#   17,
#   20,
#   136,
#   594,
#   876,
#   1180,
#   4078,
#   457,
#   454,
#   12,
#   112,
#   3,
#   2411,
#   1845,
#   1081,
#   98,
#   156,
#   2038,
#   754,
#   27,
#   1286,
#   4429,
#   494,
#   745,
#   213,
#   280,
#   632,
#   18,
#   1195,
#   1286,
#   2375,
#   18,
#   639,
#   1102,
#   82,
#   616,
#   569,
#   3319,
#   2083,
#   239,
#   59,
#   1679,
#   2705,
#   59,
#   66,
#   220,
#   2335,
#   1218,
#   632,
#   1451,
#   1192,
#   216,
#   4317,
#   510],
#  [3527,
#   3761,
#   73,
#   840,
#   248,
#   367,
#   950,
#   2545,
#   5,
#   1753,
#   4466,
#   827,
#   1321,
#   99,
#   1114,
#   56,
#   213,
#   124,
#   4247,
#   1007,
#   3621,
#   1866,
#   248,
#   119,
#   1787,
#   163,
#   64,
#   3967,
#   1513,
#   22,
#   536,
#   3182,
#   840,
#   2293,
#   935,
#   4079,
#   99,
#   827,
#   1321,
#   77,
#   211,
#   137,
#   2,
#   42,
#   1649,
#   33,
#   659,
#   1433,
#   5835,
#   30,
#   163,
#   12,
#   840,
#   2266,
#   832,
#   73,
#   840,
#   1,
#   42,
#   20,
#   3785,
#   80,
#   13,
#   4247,
#   110,
#   73,
#   840,
#   248,
#   460,
#   105,
#   486,
#   275,
#   665,
#   3182,
#   99,
#   1114,
#   123,
#   2,
#   385,
#   67,
#   2032,
#   709,
#   912,
#   1090,
#   2531,
#   202,
#   840,
#   2650,
#   5007,
#   580,
#   2315,
#   212,
#   794,
#   827,
#   1321,
#   1787,
#   1759,
#   840,
#   1657,
#   1322,
#   98,
#   3,
#   379,
#   3872,
#   721,
#   88,
#   1514,
#   4774,
#   335,
#   2277,
#   1179,
#   4247,
#   62,
#   1007,
#   3621,
#   1866,
#   300,
#   5357,
#   5008,
#   2,
#   80,
#   15,
#   927,
#   827,
#   1321,
#   2221,
#   4,
#   677,
#   1752,
#   234,
#   827,
#   1321,
#   804,
#   741,
#   34,
#   354,
#   505,
#   2,
#   110,
#   20,
#   2069,
#   1322,
#   98,
#   1644,
#   147,
#   1225,
#   8,
#   1493,
#   424,
#   840,
#   2101,
#   8,
#   66,
#   152,
#   2846,
#   277,
#   2429,
#   840,
#   250,
#   519,
#   467,
#   3468,
#   4,
#   7,
#   67,
#   168,
#   355,
#   218,
#   32,
#   49,
#   22,
#   168,
#   324,
#   34,
#   613,
#   4395,
#   1911,
#   644,
#   1866,
#   9,
#   442,
#   430,
#   191,
#   3286,
#   490,
#   840,
#   98,
#   2575,
#   1759,
#   2847,
#   35,
#   15,
#   729,
#   689,
#   1565,
#   2,
#   85,
#   2439,
#   26,
#   298,
#   577,
#   110,
#   99,
#   1243,
#   555,
#   840,
#   1949,
#   4281,
#   840,
#   26,
#   929,
#   1117,
#   111,
#   2,
#   90,
#   159,
#   1565,
#   2493,
#   840,
#   3182,
#   1274,
#   2830,
#   2901,
#   304,
#   1007,
#   3621,
#   1866,
#   4247,
#   5357,
#   3,
#   663,
#   641,
#   289,
#   832,
#   126,
#   118,
#   5358,
#   1741,
#   118,
#   2283,
#   22,
#   1730,
#   15,
#   2,
#   247,
#   4248,
#   1007,
#   2902,
#   180,
#   719,
#   310,
#   161,
#   2,
#   8,
#   21,
#   268,
#   381,
#   46,
#   5836,
#   4396,
#   1375,
#   96,
#   1637,
#   36,
#   295,
#   4397,
#   33,
#   167,
#   332,
#   2993,
#   3391,
#   707,
#   31,
#   4042,
#   707,
#   2,
#   1783,
#   102,
#   3,
#   29,
#   2657,
#   60,
#   408,
#   157,
#   21,
#   441,
#   1982,
#   318,
#   1441,
#   1777,
#   3594,
#   478,
#   1515,
#   512,
#   723,
#   8,
#   1575,
#   1291,
#   256,
#   7,
#   5055,
#   1291,
#   42,
#   2,
#   1658],
#  [8,
#   141,
#   10,
#   28,
#   1742,
#   2863,
#   38,
#   299,
#   481,
#   83,
#   2336,
#   1201,
#   104,
#   508,
#   129,
#   3,
#   137,
#   30,
#   303,
#   3469,
#   3,
#   135,
#   92,
#   22,
#   2,
#   38,
#   389,
#   541,
#   359,
#   1063,
#   4001,
#   238,
#   9,
#   1666,
#   85,
#   824,
#   286,
#   1593,
#   666,
#   1302,
#   30,
#   238,
#   123,
#   4,
#   8,
#   774,
#   239,
#   2,
#   885,
#   47,
#   649,
#   649,
#   649,
#   69,
#   2070,
#   2,
#   28],
#  [870,
#   57,
#   489,
#   2,
#   144,
#   94,
#   1922,
#   807,
#   1524,
#   36,
#   3675,
#   921,
#   132,
#   5984,
#   592,
#   2916,
#   108,
#   4392,
#   1,
#   267,
#   2267,
#   13,
#   1638,
#   225],
#  [1769,
#   181,
#   5056,
#   2459,
#   275,
#   979,
#   4043,
#   3735,
#   690,
#   1586,
#   61,
#   89,
#   179,
#   3186,
#   146,
#   1411,
#   621,
#   836,
#   2412,
#   983,
#   87,
#   321,
#   101,
#   846,
#   256,
#   150,
#   136,
#   1899,
#   1479,
#   5706,
#   1614,
#   5593,
#   364,
#   3968,
#   4,
#   1769,
#   335,
#   15,
#   1839,
#   220,
#   268,
#   1838,
#   593,
#   335,
#   4593,
#   5531,
#   1804,
#   297,
#   2,
#   45,
#   207,
#   21,
#   1943,
#   1105,
#   5477,
#   54,
#   24],
#  [2564,
#   1098,
#   1760,
#   111,
#   638,
#   511,
#   2886,
#   4136,
#   513,
#   2039,
#   51,
#   2546,
#   18,
#   280,
#   2380,
#   462,
#   306,
#   305,
#   21,
#   4137,
#   1824,
#   39,
#   21,
#   23,
#   1480,
#   2,
#   511,
#   51,
#   4,
#   2591,
#   1216,
#   1282,
#   65,
#   17,
#   3545,
#   4557,
#   874,
#   716,
#   4044,
#   2,
#   19,
#   3412,
#   5359,
#   53,
#   33,
#   21,
#   22,
#   780,
#   30,
#   4,
#   3,
#   1120,
#   2531,
#   5,
#   154,
#   120,
#   1151,
#   5,
#   2],
#  [3103,
#   85,
#   860,
#   770,
#   43,
#   2325,
#   464,
#   1592,
#   1233,
#   1190,
#   37,
#   67,
#   3103,
#   3368,
#   197,
#   223,
#   3649,
#   1043,
#   464,
#   3,
#   2460,
#   1912,
#   1628,
#   2753,
#   1489,
#   81,
#   3301,
#   283,
#   52,
#   3103,
#   657,
#   37,
#   288,
#   1657,
#   184,
#   464,
#   3571,
#   366,
#   3103,
#   52,
#   223,
#   3103,
#   2884,
#   3032,
#   679,
#   3734,
#   156,
#   162,
#   1421,
#   1412,
#   21,
#   178,
#   18,
#   6,
#   18,
#   3369,
#   393,
#   357,
#   1707,
#   486,
#   3625,
#   248,
#   2413,
#   1,
#   121,
#   481,
#   6,
#   82,
#   222,
#   158,
#   2,
#   397,
#   354,
#   5647,
#   397,
#   5647,
#   1465,
#   771,
#   1060,
#   3125,
#   369,
#   440,
#   69,
#   1120,
#   1707,
#   2186,
#   5985,
#   2,
#   2033,
#   1125,
#   1,
#   9,
#   1798,
#   287,
#   26,
#   759,
#   1236,
#   86,
#   1,
#   17,
#   3676,
#   4828,
#   190,
#   3317,
#   1133,
#   1743,
#   498,
#   828,
#   1388,
#   771,
#   62,
#   629,
#   104,
#   4249,
#   222,
#   5532,
#   3103,
#   1254,
#   21,
#   60,
#   49,
#   40,
#   596,
#   3103,
#   641,
#   558,
#   45,
#   17,
#   1566,
#   1,
#   297,
#   1,
#   316,
#   3,
#   135,
#   440,
#   11,
#   121,
#   4467,
#   194,
#   2128,
#   2135,
#   300,
#   3625],
#  [7,
#   2,
#   817,
#   3470,
#   1251,
#   46,
#   249,
#   2,
#   3,
#   70,
#   3346,
#   305,
#   56,
#   112,
#   22,
#   5,
#   817,
#   18,
#   353,
#   218,
#   43,
#   4430,
#   1795,
#   637,
#   4430,
#   7,
#   55,
#   65,
#   4318,
#   2136,
#   172,
#   3,
#   749,
#   794,
#   888,
#   5009,
#   306,
#   218,
#   43,
#   794,
#   888,
#   5009,
#   10,
#   1093,
#   683,
#   43,
#   298,
#   305,
#   5837,
#   523,
#   164,
#   47,
#   298,
#   2253,
#   90,
#   1840,
#   56,
#   2253,
#   90,
#   369,
#   331,
#   3443,
#   817,
#   188,
#   25,
#   436,
#   9,
#   490,
#   615,
#   4107,
#   2137,
#   26,
#   64,
#   141,
#   8,
#   328,
#   111,
#   21,
#   225,
#   111,
#   2461,
#   11,
#   5838,
#   2,
#   2253,
#   1840,
#   834,
#   1226,
#   4319,
#   10,
#   2291,
#   174,
#   5831,
#   27,
#   364,
#   140,
#   7,
#   328,
#   65,
#   126,
#   314,
#   298,
#   5,
#   2,
#   2706,
#   95,
#   4045,
#   673,
#   2071,
#   817,
#   85,
#   979,
#   55,
#   2934,
#   75,
#   137,
#   157,
#   73,
#   27,
#   142,
#   1788,
#   1799,
#   414,
#   4594,
#   331,
#   4,
#   758,
#   5913,
#   25,
#   314,
#   1126,
#   3443,
#   817,
#   12,
#   11,
#   268,
#   2278,
#   98,
#   137,
#   2,
#   42,
#   298,
#   5,
#   60,
#   131,
#   437,
#   560,
#   4171,
#   393,
#   99,
#   7,
#   199,
#   683,
#   43,
#   314,
#   2400,
#   5,
#   60,
#   388,
#   388],
#  [150,
#   590,
#   1673,
#   94,
#   236,
#   1520,
#   1496,
#   1520,
#   1496,
#   248,
#   361,
#   286,
#   2947,
#   207,
#   111,
#   68,
#   309,
#   1,
#   523,
#   1894,
#   56,
#   5,
#   1520,
#   1496,
#   601,
#   121,
#   560,
#   54,
#   3,
#   306,
#   24,
#   6,
#   1218,
#   1,
#   8,
#   14,
#   44,
#   36,
#   3125,
#   2276,
#   460,
#   3094,
#   121,
#   4041,
#   976,
#   680,
#   1633,
#   1633,
#   24,
#   31,
#   129,
#   530,
#   103,
#   473,
#   134,
#   213,
#   1,
#   295,
#   4,
#   1124,
#   309,
#   33,
#   35,
#   462,
#   172,
#   175,
#   2947,
#   5106,
#   980,
#   17,
#   1,
#   340,
#   976,
#   249,
#   300,
#   108,
#   8,
#   136,
#   718,
#   827,
#   5648,
#   28,
#   980,
#   4320,
#   366,
#   140,
#   2556,
#   267,
#   124,
#   212,
#   186,
#   4320,
#   401,
#   3805,
#   223,
#   296,
#   136,
#   35,
#   127,
#   8,
#   5914,
#   1983,
#   9,
#   1696,
#   44,
#   272,
#   9,
#   362,
#   1520,
#   1496,
#   382,
#   15,
#   105,
#   5649,
#   306,
#   4431,
#   784,
#   462,
#   170,
#   159,
#   198,
#   183,
#   9,
#   35,
#   784,
#   2532,
#   2887,
#   7,
#   4511,
#   4108,
#   44,
#   35,
#   523,
#   19,
#   706,
#   8,
#   95,
#   1,
#   649,
#   2497,
#   1529,
#   705,
#   248,
#   620],
#  [144,
#   3,
#   104,
#   92,
#   70,
#   338,
#   47,
#   296,
#   202,
#   174,
#   3873,
#   716,
#   5010,
#   770,
#   130,
#   1108,
#   557,
#   2,
#   217,
#   36,
#   8,
#   113,
#   7,
#   8,
#   2090,
#   514,
#   6,
#   1900,
#   26,
#   9,
#   1877,
#   1202,
#   35,
#   747,
#   26,
#   2862,
#   289,
#   2533,
#   652,
#   32,
#   103,
#   5473,
#   70,
#   453,
#   102,
#   234,
#   3527,
#   9,
#   410,
#   261,
#   1,
#   100,
#   4876,
#   1274,
#   68,
#   1337,
#   158,
#   496],
#  [841,
#   841,
#   1405,
#   2335,
#   298,
#   206,
#   101,
#   1871,
#   382,
#   1176,
#   151,
#   4360,
#   241,
#   701,
#   3440,
#   194,
#   172,
#   99,
#   764,
#   519,
#   206,
#   101,
#   61,
#   100,
#   3413,
#   177,
#   221,
#   519,
#   206,
#   101,
#   61,
#   429,
#   257,
#   3347,
#   177,
#   221,
#   177,
#   221,
#   10,
#   363,
#   244,
#   5221,
#   2484,
#   1599,
#   86,
#   80,
#   1093,
#   4672,
#   1316,
#   1805,
#   27,
#   468,
#   1177,
#   2808,
#   80,
#   1093,
#   4672,
#   12,
#   2808],
#  [143,
#   1,
#   77,
#   1534,
#   504,
#   3626,
#   2473,
#   127,
#   260,
#   358,
#   3033,
#   1,
#   2935,
#   428,
#   1020,
#   176,
#   20,
#   13,
#   594,
#   1,
#   1,
#   690,
#   210,
#   202,
#   24,
#   2473,
#   20,
#   2295,
#   4673,
#   2935,
#   201,
#   338,
#   81,
#   235,
#   2791,
#   457,
#   5,
#   127,
#   31,
#   525,
#   352,
#   91,
#   6,
#   2091,
#   280,
#   140,
#   1437,
#   550,
#   387,
#   40,
#   1303,
#   751,
#   33,
#   20,
#   715,
#   1,
#   107,
#   1872,
#   2635,
#   24,
#   190,
#   235,
#   420,
#   1422,
#   139,
#   2935,
#   8,
#   428,
#   579,
#   384,
#   500,
#   1,
#   1716,
#   390,
#   192,
#   1521,
#   173,
#   285,
#   1504],
#  [503,
#   5478,
#   662,
#   2381,
#   1470,
#   434,
#   5707,
#   63,
#   3348,
#   77,
#   1878,
#   2337,
#   5478,
#   4674,
#   3104,
#   4775,
#   2194,
#   60,
#   17,
#   649,
#   4675,
#   1304,
#   1840,
#   888,
#   676,
#   2576,
#   3874,
#   86,
#   1503,
#   5594,
#   1192,
#   28,
#   456,
#   581,
#   10,
#   41,
#   5533,
#   131,
#   2,
#   512,
#   1761,
#   273,
#   5353,
#   242,
#   2534,
#   164,
#   286,
#   805,
#   1052,
#   83,
#   74,
#   20,
#   2532,
#   2,
#   713,
#   699,
#   3,
#   7,
#   173,
#   5534,
#   1944,
#   4775,
#   3301,
#   4172,
#   2382,
#   174,
#   175,
#   3902,
#   4468,
#   193,
#   4282,
#   1199,
#   1935,
#   2948,
#   468,
#   2625,
#   1923,
#   89,
#   706,
#   9,
#   2401,
#   92,
#   39,
#   3,
#   1945,
#   400,
#   1470,
#   819,
#   157,
#   541,
#   3935,
#   43,
#   785,
#   93,
#   2577,
#   2871,
#   2031,
#   3875,
#   120,
#   886,
#   1031,
#   60,
#   69,
#   47,
#   60,
#   313,
#   1161,
#   270,
#   4248,
#   730,
#   3,
#   56,
#   1609,
#   314,
#   923,
#   279,
#   164,
#   446,
#   157,
#   239,
#   5479,
#   668,
#   27,
#   5650,
#   36,
#   157,
#   148,
#   1210,
#   4002,
#   245,
#   49,
#   257,
#   369,
#   596,
#   1494,
#   3391,
#   5986,
#   76,
#   3873,
#   97,
#   18,
#   2437,
#   5057,
#   40,
#   251,
#   117,
#   25,
#   3147,
#   1219,
#   4038,
#   168,
#   277,
#   820,
#   1362,
#   204,
#   104,
#   3471,
#   556,
#   59,
#   64,
#   1431,
#   3095,
#   295,
#   3,
#   1243,
#   5263,
#   1299,
#   65,
#   1106,
#   2917,
#   1067,
#   3148,
#   1993,
#   1976,
#   57,
#   1199,
#   67,
#   1522,
#   1846,
#   3050,
#   2230,
#   267,
#   22,
#   5316,
#   419,
#   381,
#   1945,
#   52,
#   3126,
#   28,
#   2,
#   2,
#   300,
#   17,
#   5533,
#   64,
#   2040,
#   660,
#   710,
#   4398,
#   4283,
#   401,
#   359,
#   189,
#   2,
#   1788,
#   4214,
#   300,
#   87,
#   142,
#   3349,
#   5915,
#   20,
#   161,
#   794,
#   888,
#   5,
#   169],
#  [18,
#   1514,
#   1,
#   68,
#   4,
#   694,
#   19,
#   3,
#   2872,
#   1389,
#   24,
#   5916,
#   723,
#   535,
#   100,
#   136,
#   15,
#   3,
#   1,
#   539,
#   1754,
#   96,
#   709,
#   8,
#   18,
#   403,
#   1090,
#   700,
#   648,
#   1,
#   4173,
#   37,
#   9,
#   1,
#   1072,
#   12,
#   4279,
#   1566,
#   96,
#   9,
#   17,
#   1369,
#   22,
#   1,
#   2032,
#   3,
#   28,
#   9,
#   2754,
#   29,
#   175,
#   26,
#   142,
#   2872,
#   1389,
#   578,
#   1509,
#   75,
#   527,
#   983,
#   26,
#   1,
#   1269,
#   2115,
#   83,
#   29,
#   27,
#   437,
#   1566,
#   936,
#   272,
#   37,
#   9,
#   61,
#   1824,
#   12,
#   67,
#   1,
#   1754,
#   38,
#   101,
#   28,
#   795,
#   317,
#   1,
#   77,
#   226,
#   398,
#   91,
#   668,
#   9,
#   310,
#   6,
#   2772,
#   34,
#   287,
#   787,
#   26,
#   67,
#   1,
#   17,
#   136,
#   561,
#   1615,
#   1369,
#   22,
#   1,
#   795,
#   1580,
#   3,
#   1388,
#   12,
#   259,
#   67,
#   1,
#   116,
#   468,
#   3,
#   103,
#   36,
#   153,
#   571,
#   138,
#   1754,
#   2032,
#   468,
#   584,
#   101,
#   859,
#   31],
#  [12,
#   143,
#   3705,
#   27,
#   1855,
#   341,
#   2335,
#   5706,
#   27,
#   521,
#   3472,
#   5,
#   14,
#   25,
#   856,
#   23,
#   352,
#   51,
#   2,
#   64,
#   3969,
#   298,
#   1616,
#   856,
#   1,
#   70,
#   3705,
#   587,
#   3472,
#   1584,
#   1282,
#   86,
#   3269,
#   65,
#   348,
#   7,
#   2424,
#   111,
#   310,
#   6,
#   164,
#   3212,
#   14,
#   39,
#   310,
#   6,
#   186,
#   494,
#   1225,
#   574,
#   77,
#   190],
#  [5839,
#   1447,
#   399,
#   3096,
#   2976,
#   2701,
#   155,
#   303,
#   190,
#   206,
#   301,
#   1510,
#   792,
#   3187,
#   1402,
#   2485,
#   489,
#   3735,
#   2547,
#   5107,
#   179,
#   84,
#   408,
#   4284,
#   5222,
#   5222,
#   2485,
#   987,
#   3,
#   192,
#   2462,
#   2792,
#   5222,
#   318,
#   1889,
#   2485,
#   2703,
#   2792,
#   84,
#   630,
#   2,
#   438,
#   2976,
#   1594,
#   465,
#   574,
#   10,
#   3096,
#   921,
#   110,
#   3627,
#   1966,
#   5422,
#   155,
#   812,
#   190,
#   2755,
#   1447,
#   399,
#   564,
#   3,
#   39,
#   949,
#   84,
#   24,
#   20,
#   273,
#   835],
#  [41,
#   4432,
#   60,
#   2,
#   428,
#   2266,
#   348,
#   674,
#   180,
#   437,
#   1012,
#   1813,
#   689,
#   180,
#   401,
#   391,
#   393,
#   65,
#   354,
#   685,
#   1734,
#   2707,
#   925,
#   1046,
#   840,
#   14,
#   840,
#   3970,
#   129,
#   75,
#   840,
#   16,
#   177,
#   840,
#   16,
#   418,
#   7,
#   173,
#   59,
#   392,
#   177,
#   73,
#   48,
#   220,
#   227,
#   123,
#   244,
#   597,
#   64,
#   1,
#   112,
#   116,
#   983,
#   13,
#   208,
#   65,
#   1639,
#   1434,
#   47,
#   15,
#   16,
#   386,
#   161,
#   22,
#   2021],
#  [178,
#   1,
#   164,
#   50,
#   79,
#   92,
#   23,
#   3650,
#   35,
#   355,
#   784,
#   198,
#   183,
#   245,
#   884,
#   347,
#   1363,
#   17,
#   336,
#   55,
#   761,
#   205,
#   123,
#   1,
#   543,
#   52,
#   2677,
#   3231,
#   23,
#   665,
#   999,
#   4469,
#   23,
#   50,
#   220,
#   2316,
#   1255,
#   367,
#   79,
#   2145,
#   2296,
#   50,
#   2316,
#   543,
#   2050,
#   76,
#   513,
#   2669,
#   398,
#   220,
#   1364,
#   2266,
#   48,
#   210,
#   336,
#   4,
#   685,
#   451,
#   14,
#   356,
#   11,
#   245,
#   8,
#   4676,
#   59,
#   1587,
#   1364,
#   49,
#   313,
#   1081,
#   126,
#   1975,
#   1,
#   582,
#   465,
#   4046,
#   98,
#   5360,
#   1517],
#  [322,
#   264,
#   82,
#   1451,
#   2718,
#   3148,
#   271,
#   2463,
#   87,
#   4,
#   264,
#   2254,
#   4833,
#   844,
#   4,
#   3,
#   3287,
#   71,
#   1021,
#   264,
#   246,
#   2557,
#   656,
#   3473,
#   3497,
#   1950,
#   4630,
#   3,
#   104,
#   1950,
#   270,
#   654,
#   408,
#   67,
#   774,
#   654,
#   2254,
#   120,
#   2864,
#   3677,
#   1085,
#   53,
#   33,
#   2066,
#   675,
#   3,
#   39,
#   32,
#   19,
#   2254],
#  [2,
#   2383,
#   5423,
#   5708,
#   1352,
#   85,
#   3051,
#   3474,
#   7,
#   329,
#   272,
#   96,
#   2,
#   1760,
#   101,
#   3840,
#   8,
#   811,
#   3595,
#   662,
#   1584,
#   546,
#   938,
#   2,
#   96,
#   936,
#   714,
#   1430,
#   565,
#   50,
#   277,
#   3474],
#  [5987,
#   109,
#   1,
#   92,
#   408,
#   4432,
#   1010,
#   555,
#   2,
#   86,
#   1,
#   10,
#   238,
#   1666,
#   92,
#   1170,
#   641,
#   3199,
#   1,
#   1867,
#   1096,
#   3149,
#   267,
#   925,
#   145,
#   925,
#   1945,
#   2402,
#   2888,
#   33,
#   4174,
#   2,
#   376,
#   13,
#   13,
#   5317,
#   17,
#   25,
#   116,
#   68,
#   5,
#   881,
#   32,
#   2251,
#   30,
#   876,
#   1382,
#   1108,
#   109],
#  [109,
#   5361,
#   1,
#   403,
#   13,
#   741,
#   83,
#   213,
#   811,
#   1448,
#   84,
#   1,
#   1154,
#   1,
#   303,
#   249,
#   3414,
#   18,
#   820,
#   1,
#   269,
#   122,
#   2326,
#   415,
#   5264,
#   411,
#   26,
#   35,
#   269,
#   211,
#   911,
#   1218,
#   391,
#   249,
#   56,
#   45,
#   3971,
#   613,
#   1,
#   303,
#   4321,
#   34,
#   1530,
#   1625,
#   452,
#   1107,
#   150,
#   284,
#   382,
#   1778,
#   227,
#   70,
#   2051,
#   2244,
#   940,
#   36,
#   31,
#   7,
#   117,
#   3127,
#   197,
#   394,
#   14,
#   1460,
#   3127,
#   5011,
#   117,
#   50,
#   3052,
#   5651,
#   69,
#   196,
#   411,
#   2756,
#   1984,
#   2607,
#   1068,
#   186,
#   1137,
#   465,
#   107,
#   211,
#   147,
#   31,
#   10,
#   92,
#   31,
#   15,
#   24,
#   47,
#   2608,
#   3628,
#   5762,
#   1,
#   20,
#   78,
#   2291,
#   3806,
#   452,
#   467,
#   398,
#   200,
#   51,
#   54,
#   2116,
#   259,
#   2070,
#   5012],
#  [720,
#   655,
#   322,
#   1,
#   37,
#   114,
#   373,
#   131,
#   24,
#   11,
#   32,
#   4,
#   3,
#   1473,
#   78,
#   780,
#   16,
#   47,
#   1,
#   1513,
#   798,
#   4672,
#   36,
#   31,
#   62,
#   1,
#   4,
#   3,
#   12,
#   84,
#   418,
#   550,
#   908,
#   459,
#   263,
#   4,
#   22,
#   327,
#   443,
#   465,
#   721,
#   1103,
#   284,
#   628,
#   4470,
#   374,
#   3415,
#   10,
#   105,
#   1295,
#   3,
#   38,
#   4,
#   58,
#   184,
#   459,
#   243,
#   1295,
#   4470,
#   255,
#   271,
#   193,
#   263,
#   2936,
#   4282,
#   517,
#   5362,
#   814,
#   52,
#   57,
#   263,
#   3,
#   3,
#   14,
#   5108,
#   1081,
#   129,
#   41,
#   433,
#   71,
#   544,
#   45,
#   23,
#   196,
#   92,
#   44,
#   25,
#   95,
#   231,
#   231,
#   2609],
#  [329,
#   201,
#   2889,
#   695,
#   971,
#   1149,
#   3,
#   2034,
#   970,
#   2535,
#   256,
#   2,
#   181,
#   572,
#   284,
#   742,
#   5595,
#   3320,
#   1230,
#   127,
#   2403,
#   5595,
#   1160,
#   501,
#   1664,
#   296,
#   5763,
#   2636,
#   607,
#   501,
#   381,
#   29,
#   1293,
#   37,
#   2,
#   1165,
#   4512,
#   2959,
#   5265,
#   1645,
#   1166,
#   828,
#   53,
#   6,
#   777,
#   2255,
#   554,
#   38,
#   60,
#   6,
#   659,
#   9,
#   224,
#   729,
#   644,
#   1063,
#   2,
#   344,
#   121,
#   5764,
#   370,
#   88,
#   387,
#   148,
#   374,
#   345,
#   2055,
#   4877,
#   2,
#   3706,
#   190,
#   56,
#   100,
#   11,
#   302],
#  [55,
#   431,
#   1247,
#   4834,
#   2,
#   271,
#   1298,
#   79,
#   4,
#   1636,
#   37,
#   2610,
#   1,
#   859,
#   185,
#   849,
#   68,
#   4361,
#   177,
#   59,
#   541,
#   3841,
#   649,
#   2994,
#   2829,
#   2022,
#   1510,
#   463,
#   150,
#   4214,
#   119,
#   44,
#   266,
#   230,
#   8,
#   1309,
#   1695,
#   1365,
#   74,
#   563,
#   354,
#   2170],
#  [80,
#   15,
#   177,
#   19,
#   741,
#   1983,
#   4285,
#   2,
#   145,
#   1044,
#   360,
#   1525,
#   670,
#   2084,
#   5984,
#   14,
#   2376,
#   1529,
#   185,
#   388,
#   721,
#   50,
#   651,
#   277,
#   1282,
#   276,
#   54,
#   2,
#   2960,
#   87,
#   2283,
#   2848,
#   54,
#   218,
#   2,
#   60,
#   670,
#   1203,
#   127,
#   2576,
#   218,
#   711,
#   270,
#   71,
#   2678,
#   2935,
#   4109,
#   1382,
#   127,
#   704,
#   94,
#   2084,
#   668,
#   39,
#   370,
#   2708,
#   670,
#   140,
#   28,
#   2,
#   3,
#   127,
#   446,
#   7,
#   127,
#   496,
#   309,
#   4109,
#   827,
#   374,
#   700,
#   338,
#   4080,
#   412,
#   2430,
#   181,
#   556,
#   108,
#   878,
#   462,
#   1069,
#   195,
#   2,
#   2122],
#  [124,
#   1084,
#   426,
#   68,
#   2721,
#   4362,
#   1353,
#   39,
#   40,
#   54,
#   12,
#   98,
#   54,
#   3010,
#   1283,
#   3595,
#   4399,
#   989,
#   40,
#   3673,
#   2413,
#   652,
#   28,
#   250,
#   103,
#   3342,
#   19,
#   40,
#   672,
#   68,
#   33,
#   1685,
#   485,
#   749,
#   4362,
#   2529,
#   2102,
#   105,
#   859,
#   588,
#   295,
#   4595,
#   159,
#   4399,
#   989,
#   40,
#   1585,
#   29,
#   58,
#   3321,
#   1994,
#   1446,
#   1936],
#  [303,
#   1971,
#   2,
#   1,
#   20,
#   465,
#   1316,
#   1805,
#   1350,
#   310,
#   6,
#   576,
#   428,
#   4471,
#   141,
#   1105,
#   1115,
#   371,
#   310,
#   6,
#   2],
#  [2610,
#   3370,
#   129,
#   1865,
#   3,
#   801,
#   129,
#   4138,
#   1273,
#   40,
#   10,
#   1838,
#   1298,
#   1901,
#   93,
#   449,
#   3105,
#   62,
#   1985,
#   124,
#   6,
#   1686,
#   1759,
#   2356,
#   409,
#   45,
#   565,
#   198,
#   183,
#   574,
#   27,
#   1650,
#   3528,
#   550,
#   648,
#   449,
#   648,
#   716,
#   921,
#   622,
#   474,
#   217,
#   1937,
#   25,
#   716,
#   921,
#   111,
#   258,
#   2103,
#   638,
#   242,
#   200,
#   93,
#   187,
#   156,
#   63,
#   619,
#   200,
#   1231,
#   4],
#  [1346,
#   747,
#   656,
#   291,
#   271,
#   4472,
#   859,
#   32,
#   853,
#   87,
#   152,
#   63,
#   619,
#   247,
#   585,
#   1000,
#   629,
#   663,
#   2110,
#   201,
#   374,
#   827,
#   390,
#   182,
#   3200,
#   747,
#   146,
#   232,
#   457,
#   99,
#   5652,
#   5318,
#   2,
#   496,
#   584,
#   101,
#   13,
#   5424,
#   101,
#   5917,
#   2,
#   1871,
#   1085,
#   5363,
#   384,
#   1326,
#   5653,
#   4110,
#   3210,
#   5162,
#   3807,
#   4631,
#   30,
#   846,
#   1138,
#   182,
#   3200,
#   550,
#   587,
#   863,
#   195,
#   5318,
#   3200,
#   587,
#   190,
#   3077,
#   878,
#   1847,
#   242,
#   1346,
#   2773,
#   681,
#   323],
#  [1230,
#   264,
#   346,
#   93,
#   551,
#   39,
#   9,
#   187,
#   156,
#   1139,
#   664,
#   206,
#   301,
#   110,
#   2,
#   1184,
#   277,
#   775,
#   3596,
#   5109,
#   1060,
#   9,
#   29,
#   215,
#   657,
#   37,
#   78,
#   2187,
#   1120,
#   2809,
#   2278,
#   697,
#   272,
#   747,
#   642,
#   392,
#   19,
#   698,
#   327,
#   37,
#   1359,
#   514,
#   2533,
#   1680,
#   67,
#   264,
#   1230,
#   1280,
#   2890,
#   1121,
#   26,
#   5218,
#   1995,
#   5988,
#   45,
#   142,
#   1805,
#   5535,
#   1334,
#   3546,
#   13,
#   770,
#   995,
#   5058,
#   3,
#   153,
#   119,
#   368,
#   21,
#   256,
#   190],
#  [1,
#   1169,
#   23,
#   13,
#   44,
#   3416,
#   262,
#   90,
#   22,
#   42,
#   78,
#   11,
#   1,
#   49,
#   23,
#   561,
#   777,
#   569,
#   123,
#   970,
#   3106,
#   582,
#   169,
#   989,
#   241,
#   1580,
#   403,
#   123,
#   19],
#  [268,
#   1457,
#   426,
#   2404,
#   1784,
#   2977,
#   913,
#   2404,
#   1784,
#   24,
#   131,
#   4139,
#   112,
#   349,
#   1,
#   3,
#   560,
#   2471,
#   675,
#   325,
#   70,
#   18,
#   913,
#   4466,
#   20,
#   876,
#   139,
#   403,
#   431,
#   43,
#   153,
#   2404,
#   1784,
#   3123,
#   195,
#   1721,
#   17,
#   2222,
#   374,
#   1721,
#   20,
#   431,
#   43,
#   1721,
#   3371,
#   88,
#   161,
#   434,
#   599,
#   18,
#   601,
#   121,
#   64,
#   228,
#   133,
#   431,
#   1610,
#   431,
#   43,
#   80,
#   561,
#   151,
#   324,
#   427,
#   3876,
#   422,
#   427,
#   1354,
#   1115,
#   117,
#   2753,
#   52,
#   1,
#   36,
#   2832,
#   832,
#   283,
#   369,
#   440,
#   1115,
#   2576,
#   293,
#   953,
#   1431,
#   32,
#   1610,
#   422,
#   431,
#   43,
#   1376,
#   140,
#   1248,
#   88,
#   246,
#   21,
#   431,
#   43,
#   151,
#   2223,
#   520,
#   235,
#   3372,
#   43,
#   1369,
#   3053,
#   117,
#   431,
#   43,
#   88,
#   246,
#   924,
#   322,
#   1,
#   4,
#   5162,
#   5266,
#   786,
#   583,
#   583,
#   193,
#   1919,
#   3,
#   3651,
#   679,
#   62,
#   427,
#   103,
#   15,
#   306,
#   431,
#   43,
#   35,
#   4632,
#   5,
#   1456,
#   1268,
#   1223,
#   6,
#   2690,
#   164,
#   1,
#   7,
#   895,
#   162,
#   162,
#   80,
#   13,
#   1146,
#   17,
#   3165,
#   45,
#   97,
#   430,
#   293,
#   430,
#   1600,
#   103,
#   1685,
#   675,
#   325,
#   3123,
#   736,
#   1744,
#   736,
#   282,
#   596,
#   620,
#   450,
#   1078,
#   620,
#   139,
#   19,
#   1,
#   410,
#   1023],
#  [293,
#   84,
#   2,
#   72,
#   138,
#   144,
#   2,
#   555,
#   84,
#   402,
#   496,
#   918,
#   7,
#   1875,
#   764,
#   15,
#   56,
#   385,
#   84,
#   30,
#   116,
#   1922,
#   483,
#   545,
#   402,
#   80,
#   5,
#   3,
#   44,
#   24,
#   277,
#   31,
#   609,
#   9,
#   189,
#   545,
#   158,
#   402,
#   4140,
#   16,
#   225,
#   703,
#   223,
#   3736,
#   436,
#   18,
#   1882,
#   2506,
#   84,
#   408,
#   408,
#   3707,
#   509,
#   1220,
#   703,
#   189,
#   110,
#   1080,
#   3707,
#   364,
#   636,
#   1267,
#   311,
#   2626,
#   381,
#   3707,
#   630,
#   66,
#   11,
#   2440,
#   27,
#   3529,
#   311,
#   595,
#   5319,
#   120,
#   191,
#   2146,
#   210,
#   125,
#   39,
#   402,
#   207,
#   844,
#   162,
#   67,
#   9,
#   107,
#   1075,
#   213,
#   15,
#   129,
#   4138,
#   656,
#   5425,
#   181,
#   5840,
#   128,
#   318,
#   974,
#   6,
#   461,
#   55,
#   304,
#   470,
#   2626,
#   2213,
#   3267,
#   3417,
#   5654,
#   4250,
#   363,
#   930,
#   5654,
#   671,
#   1634,
#   285,
#   591,
#   4558,
#   1594,
#   184,
#   318,
#   4513,
#   930,
#   671,
#   679,
#   162,
#   1878,
#   116,
#   1197,
#   614,
#   256,
#   812,
#   2317,
#   197,
#   1066,
#   38,
#   128,
#   1882,
#   614,
#   336,
#   4,
#   2486,
#   45,
#   268,
#   55,
#   413,
#   3,
#   900,
#   12,
#   2589,
#   1882,
#   831,
#   1946,
#   373,
#   2464,
#   687,
#   813,
#   724,
#   551,
#   93,
#   157,
#   434,
#   5426,
#   3498,
#   86,
#   64,
#   98,
#   2,
#   1640,
#   1024,
#   152,
#   69,
#   44,
#   3903,
#   1185,
#   2,
#   66,
#   80,
#   111,
#   142,
#   108,
#   336,
#   4,
#   1076,
#   1197,
#   614,
#   142,
#   3498,
#   1924,
#   103,
#   95,
#   88,
#   376,
#   224,
#   550,
#   186,
#   614,
#   981,
#   3498,
#   454,
#   927,
#   4322,
#   2357,
#   259,
#   614,
#   88,
#   71,
#   335,
#   566,
#   262,
#   317,
#   138,
#   719,
#   5,
#   44,
#   18,
#   1882,
#   915,
#   2,
#   506,
#   900,
#   12,
#   202,
#   35,
#   355,
#   140,
#   4,
#   2],
#  [1062,
#   284,
#   296,
#   698,
#   513,
#   1118,
#   363,
#   3786,
#   216,
#   381,
#   644,
#   5110,
#   821,
#   38,
#   3786,
#   199,
#   1,
#   2558,
#   1783,
#   79,
#   234,
#   2,
#   147,
#   804,
#   50,
#   83,
#   319,
#   594,
#   681,
#   447,
#   26,
#   4,
#   5059,
#   2679,
#   5163,
#   925,
#   4633,
#   2937,
#   3842,
#   2405,
#   82,
#   16,
#   144,
#   5761,
#   3547,
#   2283,
#   833,
#   9,
#   2306,
#   713,
#   87,
#   1492,
#   475,
#   730,
#   123,
#   3201,
#   314,
#   475,
#   77,
#   1626,
#   4878,
#   111,
#   3496,
#   61,
#   2256,
#   77,
#   4323,
#   115,
#   1397,
#   1365,
#   2,
#   99,
#   673,
#   2327,
#   181,
#   887,
#   3808,
#   296,
#   475,
#   871,
#   88,
#   468,
#   9,
#   16,
#   38,
#   158,
#   720,
#   72,
#   294,
#   151,
#   1024,
#   1134,
#   2556,
#   227,
#   38,
#   84,
#   1365,
#   1433,
#   84,
#   214],
#  [1458,
#   1,
#   587,
#   3708,
#   731,
#   850,
#   1579,
#   5223,
#   1220,
#   1214,
#   862,
#   648,
#   584,
#   850,
#   708,
#   1,
#   896,
#   994,
#   731,
#   81,
#   128,
#   7,
#   677,
#   513,
#   2039,
#   43,
#   350,
#   17,
#   215,
#   656,
#   3762,
#   848,
#   151,
#   4725,
#   3054,
#   27,
#   527,
#   3,
#   501,
#   366,
#   18,
#   701,
#   283,
#   1113,
#   504,
#   1545,
#   250,
#   11,
#   1,
#   23,
#   1112,
#   141,
#   414],
#  [18,
#   109,
#   2,
#   2138,
#   6,
#   1014,
#   2431,
#   74,
#   2658,
#   1525,
#   73,
#   1273,
#   1,
#   3150,
#   75,
#   785,
#   106,
#   3965,
#   1731,
#   4726,
#   2659,
#   50,
#   234,
#   5596,
#   315,
#   3265,
#   142,
#   293,
#   1426,
#   98,
#   240,
#   5427,
#   1,
#   3,
#   48,
#   1567,
#   2456,
#   600,
#   315,
#   1701,
#   1617,
#   79,
#   741,
#   14,
#   484,
#   1729,
#   255,
#   107,
#   331,
#   3843,
#   2138,
#   652,
#   270,
#   5427,
#   5596,
#   1218,
#   8,
#   453,
#   1739,
#   110,
#   58,
#   184,
#   2658,
#   1525,
#   46,
#   3,
#   6,
#   379,
#   24],
#  [478,
#   7,
#   55,
#   204,
#   2,
#   25,
#   4213,
#   38,
#   116,
#   1380,
#   4,
#   399,
#   1912,
#   64,
#   115,
#   177,
#   1377,
#   404,
#   42,
#   421,
#   4,
#   424,
#   607,
#   1,
#   231,
#   140,
#   347,
#   523,
#   404,
#   4,
#   243,
#   70,
#   3499,
#   1215,
#   4677,
#   311,
#   1497,
#   2136,
#   326,
#   1426,
#   2789,
#   2033,
#   3530,
#   213,
#   200,
#   379,
#   71,
#   1,
#   347,
#   802,
#   240,
#   311,
#   624,
#   2432,
#   347,
#   73],
#  [502,
#   610,
#   20,
#   132,
#   1,
#   1716,
#   1523,
#   5839,
#   384,
#   83,
#   3018,
#   311,
#   1064,
#   3127,
#   5428,
#   4175,
#   3034,
#   2245,
#   53,
#   33,
#   5536,
#   3127,
#   17,
#   20,
#   1845,
#   626,
#   4468,
#   500,
#   74],
#  [1553,
#   476,
#   885,
#   10,
#   276,
#   737,
#   32,
#   853,
#   288,
#   1097,
#   5013,
#   2660,
#   1365,
#   524,
#   867,
#   494,
#   745,
#   152,
#   48,
#   390,
#   916,
#   609,
#   595,
#   3,
#   209,
#   928,
#   75,
#   1275,
#   450,
#   244,
#   160,
#   431,
#   607,
#   1266,
#   782,
#   132,
#   1576,
#   73,
#   48,
#   1855,
#   847,
#   59,
#   1332,
#   1016,
#   132,
#   362,
#   3877,
#   16,
#   1182,
#   57,
#   3151,
#   3474,
#   518,
#   2660,
#   181,
#   4,
#   1680,
#   1001,
#   3186,
#   617,
#   4,
#   3270,
#   76,
#   185,
#   26,
#   116,
#   5841,
#   180,
#   193,
#   145,
#   3213,
#   1667,
#   40,
#   1183,
#   1411,
#   352,
#   697,
#   4,
#   1951,
#   494,
#   4727,
#   76,
#   40,
#   2377,
#   17,
#   585,
#   5842,
#   3373,
#   3629,
#   2743,
#   102,
#   1879,
#   3763,
#   1603,
#   28,
#   12,
#   169,
#   1603,
#   3630,
#   381,
#   331,
#   309,
#   34,
#   3322,
#   1013,
#   806,
#   55,
#   239,
#   1,
#   1196,
#   4774,
#   5060,
#   4363,
#   1135,
#   2873,
#   87,
#   4081,
#   2439,
#   4728,
#   3444,
#   31,
#   290,
#   408,
#   40,
#   202,
#   1270,
#   58,
#   5164,
#   1423,
#   750,
#   40,
#   1285,
#   1770,
#   47,
#   3937,
#   307,
#   1830,
#   4835,
#   92,
#   1518,
#   904,
#   12,
#   107,
#   224,
#   100,
#   136,
#   46,
#   443,
#   157,
#   339,
#   3374,
#   253,
#   1552,
#   827,
#   135,
#   1846,
#   1452,
#   88,
#   837,
#   1570,
#   199,
#   408,
#   12,
#   1438,
#   1493,
#   75,
#   1317,
#   4908,
#   53,
#   33,
#   314,
#   504,
#   367,
#   424,
#   5165,
#   105,
#   1375,
#   1255,
#   22,
#   4141,
#   3936,
#   2377,
#   17,
#   585,
#   423,
#   282,
#   1073,
#   565,
#   3593,
#   3302,
#   5014,
#   5267,
#   2123,
#   1674,
#   5268,
#   21,
#   2891,
#   602,
#   157,
#   465,
#   466,
#   518,
#   4958,
#   1605,
#   690,
#   52,
#   40,
#   58,
#   760,
#   146,
#   2246,
#   3475,
#   5269,
#   1872,
#   27,
#   5224,
#   298,
#   58,
#   461,
#   674,
#   61,
#   3475,
#   5015,
#   2123,
#   3009,
#   14,
#   306,
#   2658,
#   70,
#   500,
#   1771,
#   2849,
#   1050,
#   1369,
#   18,
#   806,
#   4286,
#   366,
#   159,
#   381,
#   5364,
#   341,
#   429,
#   14,
#   3572,
#   2123,
#   564,
#   4215,
#   787,
#   3,
#   43,
#   177,
#   3017,
#   668,
#   917,
#   1138,
#   2150,
#   70,
#   52,
#   3878,
#   231,
#   270,
#   4678,
#   857,
#   615,
#   57,
#   1722,
#   699,
#   199,
#   2891,
#   602,
#   3970,
#   2810,
#   497,
#   52,
#   3878,
#   4678,
#   1743,
#   1562,
#   524,
#   2123,
#   222,
#   320,
#   711,
#   314,
#   763,
#   693,
#   500,
#   132,
#   240,
#   188,
#   1723,
#   1119,
#   69,
#   3879,
#   3573,
#   40,
#   63,
#   1043,
#   190,
#   2610,
#   349,
#   2961,
#   75,
#   629,
#   174,
#   41,
#   1949,
#   12,
#   146,
#   146,
#   167,
#   37,
#   36,
#   384,
#   4287,
#   271,
#   911,
#   201,
#   2023,
#   271,
#   1515,
#   5597,
#   1691,
#   291,
#   2949,
#   3972,
#   378,
#   18,
#   1138,
#   14,
#   314,
#   28,
#   213,
#   200,
#   1097,
#   3035,
#   5105,
#   10,
#   11,
#   147,
#   226,
#   4364,
#   287,
#   99,
#   4909,
#   286,
#   2709,
#   1958,
#   1508,
#   267,
#   122,
#   727,
#   4473,
#   161,
#   52,
#   248,
#   2186,
#   1365,
#   238,
#   11,
#   275,
#   1,
#   1490,
#   32,
#   497,
#   287,
#   12,
#   2710,
#   351,
#   110,
#   355,
#   2337,
#   952,
#   144,
#   749,
#   28,
#   504,
#   2257,
#   141,
#   248],
#  [1218,
#   2,
#   70,
#   112,
#   1580,
#   34,
#   669,
#   47,
#   112,
#   862,
#   72,
#   915,
#   75,
#   224,
#   456,
#   1317,
#   112,
#   839,
#   703,
#   39,
#   71,
#   2,
#   282,
#   239,
#   2,
#   457,
#   1984,
#   4324],
#  [475,
#   4959,
#   1139,
#   444,
#   9,
#   4464,
#   793,
#   5983,
#   279,
#   37,
#   152,
#   2441,
#   6,
#   752,
#   4879,
#   3548,
#   726,
#   4003,
#   488,
#   1792,
#   2367,
#   1681,
#   4082,
#   2224,
#   654,
#   4003,
#   930,
#   5537,
#   4879,
#   5166,
#   4879,
#   2711,
#   86,
#   702,
#   4879,
#   106,
#   2774,
#   1898,
#   1181,
#   3704,
#   339,
#   2611,
#   4879,
#   4879,
#   69,
#   1069,
#   285,
#   1274,
#   514,
#   1856,
#   345,
#   4879,
#   160,
#   57,
#   4910,
#   8,
#   3166,
#   63,
#   339,
#   2040,
#   359,
#   4959,
#   381,
#   4879,
#   1986,
#   87,
#   5365,
#   1120,
#   1554,
#   359,
#   176,
#   4879,
#   836,
#   1444,
#   447,
#   2031,
#   1280,
#   9,
#   799,
#   468,
#   1808,
#   1183,
#   1411,
#   359,
#   2,
#   219,
#   698,
#   5709],
#  [10,
#   340,
#   4,
#   2,
#   9,
#   78,
#   2187,
#   2,
#   3078,
#   98,
#   741,
#   41,
#   51,
#   15,
#   70,
#   453,
#   333,
#   3597,
#   2,
#   159,
#   176,
#   2204,
#   1200,
#   2204,
#   2708,
#   1284,
#   2204,
#   14,
#   1086,
#   1354,
#   200,
#   21,
#   2204,
#   1967,
#   239,
#   2,
#   5843,
#   894,
#   409,
#   1200,
#   2351,
#   2204,
#   6,
#   330,
#   52,
#   1628,
#   1093,
#   35,
#   545,
#   175,
#   26,
#   996],
#  [89,
#   214,
#   302,
#   109,
#   1,
#   421,
#   111,
#   1099,
#   47,
#   111,
#   699,
#   29,
#   352,
#   59,
#   1030,
#   2,
#   42,
#   237,
#   959,
#   362,
#   55,
#   405,
#   1413,
#   3247,
#   223,
#   24,
#   1952,
#   10,
#   111,
#   5366,
#   344,
#   121,
#   10,
#   1717,
#   31,
#   18,
#   398,
#   162,
#   10,
#   22,
#   168,
#   4911,
#   245,
#   385,
#   302,
#   228,
#   46,
#   25,
#   1,
#   12,
#   113,
#   60,
#   827,
#   859,
#   939],
#  [741,
#   589,
#   2,
#   381,
#   3702,
#   137,
#   2,
#   6,
#   137,
#   60,
#   6,
#   2,
#   23,
#   1900,
#   1039,
#   891,
#   15,
#   5,
#   1327,
#   2,
#   82,
#   993,
#   71,
#   943,
#   164,
#   99,
#   3078,
#   73,
#   279,
#   534,
#   16,
#   4,
#   2,
#   4,
#   1360,
#   2,
#   2164,
#   218,
#   357,
#   153,
#   99,
#   523,
#   58,
#   4729,
#   99,
#   3350,
#   300,
#   137,
#   2,
#   4596,
#   80,
#   241,
#   300,
#   276,
#   917,
#   147,
#   2,
#   23,
#   50,
#   3569,
#   723,
#   1575,
#   90,
#   568,
#   30,
#   13,
#   3246,
#   1960,
#   645,
#   58,
#   4729,
#   98,
#   341,
#   262,
#   2995,
#   119,
#   3366,
#   3596,
#   2,
#   2625,
#   173,
#   92,
#   560,
#   271,
#   2627,
#   2978,
#   324,
#   3904,
#   1105,
#   28,
#   3,
#   512,
#   5710,
#   335,
#   241,
#   1235,
#   58,
#   4729,
#   1041,
#   2651,
#   7,
#   22,
#   138,
#   15,
#   1,
#   507,
#   15,
#   15,
#   55,
#   4474,
#   652,
#   22,
#   2,
#   5423,
#   307,
#   4398,
#   120,
#   3128,
#   65,
#   1353,
#   5765,
#   652,
#   22,
#   5,
#   1,
#   7,
#   681,
#   58,
#   4729,
#   4433,
#   955,
#   3163,
#   993,
#   2744,
#   2195,
#   45,
#   324,
#   5316,
#   262,
#   139,
#   462,
#   2,
#   645,
#   1430,
#   163,
#   15,
#   5,
#   90,
#   147,
#   483,
#   1,
#   262,
#   276,
#   1430,
#   64,
#   282,
#   2,
#   28,
#   459,
#   15,
#   1,
#   14,
#   481,
#   1535,
#   70,
#   8,
#   3650,
#   447,
#   15,
#   1709,
#   4216,
#   4361,
#   1029,
#   973,
#   338,
#   114,
#   292,
#   552,
#   3474,
#   469,
#   3149,
#   43,
#   1181],
#  [3418,
#   2317,
#   4912,
#   1702,
#   1414,
#   24,
#   149,
#   62,
#   5111,
#   1179,
#   4634,
#   24,
#   32,
#   31,
#   164,
#   251,
#   493,
#   1063,
#   104,
#   646,
#   281,
#   2307,
#   2656,
#   4634,
#   85,
#   3303,
#   5711,
#   4956,
#   298,
#   1491,
#   1568,
#   1,
#   804,
#   347,
#   4,
#   895,
#   97,
#   1,
#   399,
#   473,
#   3,
#   169,
#   37,
#   216,
#   310,
#   140,
#   4111,
#   2015,
#   591,
#   960,
#   11,
#   4913,
#   227,
#   2592,
#   532,
#   1048,
#   143,
#   4634,
#   1814,
#   1491,
#   1568,
#   2258,
#   248,
#   961,
#   7,
#   1685,
#   4634,
#   138,
#   231,
#   3126,
#   3375,
#   24,
#   159,
#   74,
#   14,
#   1679,
#   2150,
#   1023,
#   4047,
#   4634],
#  [507,
#   2035,
#   101,
#   1037,
#   7,
#   4288,
#   635,
#   1461,
#   2195,
#   238,
#   4909,
#   1433,
#   527,
#   1469,
#   495,
#   32,
#   226,
#   147,
#   773,
#   298,
#   333,
#   1735,
#   4914,
#   3107,
#   281,
#   91,
#   147,
#   773,
#   739,
#   13,
#   6,
#   152,
#   333,
#   1366,
#   1951,
#   3107,
#   611,
#   392,
#   99,
#   14,
#   234,
#   73,
#   495,
#   66,
#   871,
#   65,
#   4318,
#   1522,
#   3,
#   129,
#   379,
#   17,
#   265,
#   244,
#   5918,
#   852,
#   1376,
#   134,
#   525,
# ...
#   754,
#   1,
#   326,
#   121,
#   237,
#   1680,
#   3274,
#   3525,
#   2443,
#   2249,
#   1,
#   162,
#   582,
#   3074,
#   38,
#   328,
#   4901,
#   805,
#   3608,
#   365,
#   2,
#   679,
#   72,
#   3314,
#   2405,
#   136,
#   101,
#   743,
#   54,
#   19,
#   49,
#   2042,
#   595,
#   540,
#   3826,
#   3348,
#   3525,
#   809,
#   2,
#   136,
#   101,
#   26,
#   10,
#   426,
#   132,
#   93,
#   22,
#   873,
#   250,
#   39,
#   23,
#   96,
#   2,
#   46,
#   5,
#   86,
#   132,
#   93,
#   13,
#   44],
#  [1035,
#   340,
#   2,
#   516,
#   63,
#   619,
#   396,
#   85,
#   2,
#   776,
#   849,
#   74,
#   3118,
#   2046,
#   4377,
#   797,
#   439,
#   5240,
#   969,
#   307,
#   1496,
#   2359,
#   1035,
#   2525,
#   294,
#   123,
#   111,
#   436,
#   4408,
#   1381,
#   241,
#   396,
#   3208,
#   245,
#   1410,
#   1517,
#   5850,
#   3,
#   1644,
#   1496,
#   644,
#   5602,
#   18,
#   56,
#   109,
#   29,
#   16,
#   803,
#   51,
#   5029,
#   2,
#   2525,
#   1960,
#   252,
#   324,
#   492,
#   1268,
#   3189,
#   281,
#   898,
#   426,
#   19,
#   328,
#   120,
#   1,
#   953,
#   2030,
#   945,
#   38,
#   5820,
#   1022,
#   72,
#   4385,
#   898,
#   1682,
#   776,
#   664,
#   3,
#   3,
#   2837,
#   23,
#   1107,
#   2149,
#   1280,
#   694,
#   262,
#   2912,
#   868,
#   635,
#   2,
#   586,
#   300,
#   161,
#   163,
#   50,
#   2292,
#   12,
#   20,
#   767,
#   583,
#   220,
#   3987,
#   842,
#   2287,
#   39,
#   516,
#   305,
#   1140],
#  [1256,
#   1,
#   829,
#   3073,
#   272,
#   13,
#   778,
#   250,
#   1979,
#   1657,
#   1356,
#   136,
#   1765,
#   9,
#   2814,
#   471,
#   4755,
#   2409,
#   414,
#   636,
#   1412,
#   3,
#   1277,
#   377,
#   908,
#   38,
#   74,
#   5100,
#   1342,
#   2606,
#   1,
#   3016,
#   638,
#   24,
#   4175,
#   62,
#   198,
#   169,
#   570,
#   1035,
#   626,
#   360,
#   509,
#   790,
#   268,
#   1056,
#   74,
#   265,
#   1136,
#   2194,
#   1382,
#   224,
#   5994,
#   654,
#   114,
#   638,
#   638,
#   1157,
#   3595,
#   451,
#   691,
#   691,
#   85,
#   691,
#   267,
#   638,
#   1102,
#   278],
#  [3,
#   5885,
#   2991,
#   53,
#   1871,
#   1554,
#   2991,
#   150,
#   58,
#   770,
#   1459,
#   238,
#   2015,
#   1211,
#   4482,
#   1286,
#   583,
#   487,
#   166,
#   209,
#   153,
#   1058,
#   2034,
#   364,
#   151,
#   90,
#   161,
#   1813,
#   1515,
#   161,
#   67,
#   706,
#   81,
#   863,
#   195,
#   1554,
#   1369,
#   5009,
#   464,
#   88,
#   161,
#   1499,
#   25,
#   860,
#   25,
#   85,
#   54,
#   1,
#   234,
#   212,
#   16,
#   5411,
#   671,
#   436,
#   1,
#   285,
#   29,
#   121,
#   205,
#   70,
#   1783,
#   26,
#   2419,
#   34,
#   287,
#   38,
#   13,
#   186,
#   793,
#   45,
#   6,
#   10,
#   328,
#   610,
#   788,
#   460,
#   2676,
#   2991,
#   127,
#   136,
#   873,
#   103,
#   1045,
#   6,
#   42,
#   31,
#   5369,
#   4322,
#   2357,
#   1003,
#   3450,
#   73,
#   48,
#   67,
#   456,
#   13,
#   4185],
#  [73,
#   2,
#   174,
#   88,
#   3386,
#   1936,
#   2798,
#   2160,
#   431,
#   135,
#   10,
#   2042,
#   1936,
#   2825,
#   397,
#   1127,
#   4941,
#   357,
#   54,
#   4588,
#   5188,
#   1,
#   4611,
#   79,
#   5822,
#   312,
#   1,
#   2252,
#   34,
#   82,
#   213,
#   162,
#   55,
#   170,
#   2363,
#   5963,
#   1,
#   479,
#   91,
#   4523,
#   91,
#   1174,
#   4253,
#   149,
#   121,
#   390,
#   19,
#   491,
#   275,
#   149,
#   406,
#   118,
#   3789,
#   245,
#   2952,
#   1423,
#   3834,
#   954,
#   856,
#   5188,
#   1560,
#   27,
#   5783,
#   372,
#   74,
#   2220,
#   1584,
#   276,
#   387,
#   754,
#   2363,
#   4976,
#   5650,
#   22,
#   4486,
#   2270,
#   1230,
#   2301,
#   620,
#   2319,
#   4010,
#   2559,
#   100,
#   36,
#   31,
#   163,
#   141,
#   23,
#   95,
#   13,
#   2656,
#   15,
#   589,
#   11,
#   112,
#   14,
#   168,
#   2502,
#   5750,
#   116,
#   23,
#   1,
#   490,
#   1609,
#   928,
#   2233,
#   2011,
#   17,
#   179,
#   324,
#   1909,
#   24,
#   88,
#   1651,
#   2952,
#   13,
#   2502,
#   5750,
#   24,
#   3579,
#   4461,
#   2502,
#   5750,
#   1518,
#   133,
#   416,
#   1588,
#   2672,
#   793,
#   4607,
#   989,
#   2409,
#   4,
#   2055,
#   4379,
#   2968,
#   330],
#  [3928,
#   15,
#   21,
#   255,
#   92,
#   96,
#   1802,
#   870,
#   475,
#   1784,
#   36,
#   109,
#   475,
#   1784,
#   109,
#   2,
#   2,
#   115,
#   14,
#   1404,
#   290,
#   616,
#   2,
#   609,
#   471,
#   137,
#   1443,
#   183,
#   42,
#   31,
#   6,
#   2,
#   1127,
#   3714,
#   348,
#   24,
#   754,
#   4187,
#   88,
#   50,
#   1292,
#   159,
#   5254,
#   4913,
#   5254,
#   521,
#   253,
#   199,
#   2,
#   1,
#   2903,
#   3,
#   48,
#   4,
#   475,
#   1784,
#   475,
#   1784,
#   4917,
#   128,
#   1262,
#   2,
#   1262,
#   4917,
#   128,
#   1293,
#   17,
#   83,
#   160,
#   62,
#   1784,
#   4619,
#   43,
#   260,
#   2404,
#   1784,
#   72,
#   4084,
#   49,
#   498,
#   397,
#   2,
#   425,
#   947,
#   4,
#   186,
#   62,
#   475,
#   1784,
#   989,
#   3028,
#   430,
#   945,
#   645,
#   484,
#   49],
#  [533,
#   643,
#   41,
#   38,
#   2,
#   3968,
#   1988,
#   870,
#   161,
#   4586,
#   770,
#   643,
#   377,
#   28,
#   4451,
#   3839,
#   1832,
#   1548,
#   3246,
#   208,
#   2573,
#   829,
#   6,
#   146,
#   21,
#   32,
#   30,
#   377,
#   874,
#   842,
#   1535,
#   1076,
#   3435,
#   456,
#   770,
#   1417,
#   208,
#   5188,
#   30,
#   314,
#   3675,
#   757,
#   189,
#   94,
#   1465,
#   1052,
#   150,
#   842,
#   1535,
#   86,
#   1144,
#   1379,
#   189,
#   390,
#   247,
#   447,
#   445,
#   4,
#   2242,
#   1,
#   299,
#   102,
#   191,
#   515,
#   856,
#   4308,
#   263,
#   53,
#   33,
#   8,
#   14,
#   5068,
#   3457,
#   53,
#   33,
#   4742,
#   1548,
#   208,
#   860,
#   2917,
#   1548,
#   81,
#   592,
#   3457,
#   1635,
#   2090,
#   1482,
#   266,
#   108,
#   2,
#   842,
#   208,
#   3352,
#   339,
#   1482,
#   1605,
#   8,
#   32,
#   58,
#   5175,
#   3501,
#   110,
#   873,
#   1326,
#   3839,
#   1832,
#   488,
#   1999,
#   842,
#   5026,
#   217,
#   329,
#   53,
#   3638,
#   83,
#   2905,
#   8,
#   62,
#   1883,
#   842,
#   8,
#   2293,
#   30,
#   5878],
#  [4,
#   647,
#   109,
#   2,
#   274,
#   300,
#   543,
#   96,
#   44,
#   673,
#   49,
#   46,
#   1317,
#   49,
#   46,
#   15,
#   32,
#   621,
#   25,
#   1129,
#   852,
#   112,
#   1129,
#   571,
#   952,
#   4283,
#   49,
#   852,
#   16,
#   1926,
#   83,
#   2389,
#   437,
#   1,
#   249,
#   729,
#   41,
#   18,
#   289,
#   249,
#   577,
#   112,
#   2864,
#   3677,
#   55,
#   577,
#   2278,
#   3095,
#   35,
#   4695,
#   3843,
#   394,
#   8,
#   147,
#   137,
#   193,
#   407,
#   1909,
#   82,
#   1374,
#   911,
#   839,
#   525,
#   352,
#   792,
#   267,
#   41,
#   4695,
#   92,
#   23,
#   1521,
#   2,
#   813,
#   80,
#   15,
#   17,
#   155,
#   4,
#   1731,
#   5323,
#   664,
#   49,
#   2369,
#   169,
#   651,
#   5154,
#   879,
#   174,
#   1144,
#   3,
#   1363,
#   469,
#   347,
#   17,
#   1987,
#   729,
#   692,
#   3395,
#   63,
#   663,
#   36,
#   1034,
#   296,
#   17,
#   1151,
#   1742,
#   383,
#   4661,
#   15,
#   35,
#   112,
#   1403,
#   3846,
#   764,
#   10,
#   2,
#   112,
#   32,
#   323,
#   80,
#   3924,
#   66,
#   143,
#   210,
#   610,
#   39,
#   116,
#   745,
#   4818,
#   90,
#   186,
#   211,
#   44,
#   218,
#   1182,
#   1,
#   4,
#   3011],
#  [4080,
#   1460,
#   81,
#   130,
#   3977,
#   93,
#   187,
#   2405,
#   4326,
#   930,
#   430,
#   5634,
#   2290,
#   3387,
#   1145,
#   553,
#   143,
#   223,
#   2,
#   4431,
#   4080,
#   2108,
#   503,
#   445,
#   417,
#   2943,
#   4501,
#   1797,
#   739,
#   951,
#   3387,
#   2654,
#   5,
#   108,
#   435,
#   2290,
#   3764,
#   81,
#   130,
#   2847,
#   843,
#   810,
#   2161,
#   304,
#   23,
#   240,
#   334,
#   81,
#   59,
#   1903,
#   770,
#   2386,
#   75,
#   32,
#   118,
#   753,
#   921,
#   319,
#   2,
#   2831,
#   5,
#   304,
#   11,
#   11,
#   521,
#   1162,
#   1543,
#   81,
#   130,
#   488,
#   1160,
#   90,
#   1317,
#   521,
#   3441,
#   2448,
#   11,
#   2215],
#  [989,
#   3028,
#   430,
#   1265,
#   716,
#   351,
#   1239,
#   1347,
#   535,
#   1035,
#   2103,
#   223,
#   248,
#   535,
#   31,
#   427,
#   9,
#   250,
#   103,
#   510,
#   427,
#   9,
#   2244,
#   39,
#   2,
#   1663,
#   20,
#   4,
#   823,
#   2,
#   201,
#   31,
#   2296,
#   1503,
#   35,
#   15,
#   34,
#   80,
#   5,
#   253,
#   34,
#   12,
#   109,
#   2,
#   52,
#   253,
#   2,
#   627,
#   19,
#   97,
#   3136,
#   101,
#   5,
#   2244,
#   2,
#   596,
#   69,
#   427,
#   9,
#   2244,
#   214,
#   665,
#   2,
#   4429],
#  [18,
#   293,
#   301,
#   231,
#   42,
#   5561,
#   717,
#   1354,
#   418,
#   301,
#   16,
#   206,
#   16,
#   15,
#   206,
#   16,
#   301,
#   16,
#   469,
#   543,
#   1658,
#   255,
#   512,
#   51,
#   5,
#   47,
#   1,
#   1055,
#   101,
#   49,
#   2977,
#   48,
#   1708,
#   3004,
#   846,
#   14,
#   409,
#   10,
#   89,
#   10,
#   428,
#   10,
#   10,
#   1460,
#   484,
#   150,
#   3733,
#   3695,
#   1017,
#   3733,
#   2422,
#   1283,
#   3399,
#   1132,
#   1132,
#   4630,
#   1,
#   1354,
#   1741,
#   1490,
#   2585,
#   1,
#   597,
#   1949,
#   301,
#   117,
#   105,
#   206,
#   5156,
#   5181,
#   211,
#   249,
#   2436,
#   42,
#   199,
#   467,
#   6,
#   1987,
#   447,
#   712,
#   272,
#   712,
#   766,
#   610,
#   555,
#   5186,
#   304,
#   717,
#   50,
#   703,
#   179,
#   343,
#   1390,
#   1426,
#   1],
#  [2,
#   13,
#   2,
#   829,
#   965,
#   694,
#   68,
#   277,
#   868,
#   377,
#   211,
#   271,
#   1052,
#   3092,
#   3,
#   189,
#   744,
#   631,
#   2516,
#   19,
#   1715,
#   1697,
#   357,
#   631,
#   4718,
#   13,
#   60,
#   965,
#   3,
#   89,
#   530,
#   829,
#   3841,
#   357,
#   30,
#   899,
#   7,
#   55,
#   799,
#   2835,
#   3905,
#   91,
#   932,
#   3940,
#   277,
#   1165,
#   23,
#   2890,
#   62,
#   333,
#   774,
#   389,
#   2807,
#   273,
#   2,
#   647,
#   283,
#   2,
#   631,
#   534,
#   122,
#   1052,
#   19,
#   3314,
#   3439,
#   2164,
#   29,
#   530,
#   3680,
#   551,
#   1033,
#   8,
#   20,
#   51,
#   4,
#   99,
#   19,
#   531,
#   919,
#   202,
#   118,
#   2,
#   940,
#   246,
#   907,
#   1715,
#   1734,
#   369,
#   19,
#   245,
#   2264,
#   651,
#   1130,
#   37,
#   460,
#   1329,
#   34,
#   138,
#   276,
#   2510,
#   246],
#  [55,
#   970,
#   214,
#   321,
#   1491,
#   1568,
#   30,
#   2,
#   153,
#   577,
#   779,
#   136,
#   843,
#   14,
#   72,
#   138,
#   2,
#   3,
#   39,
#   1148,
#   768,
#   1381,
#   2710,
#   1525,
#   346,
#   127,
#   13,
#   771,
#   19,
#   1412,
#   2646,
#   181,
#   449,
#   2524,
#   192,
#   2166,
#   3484,
#   105,
#   437,
#   1230,
#   1463,
#   918,
#   4724,
#   127,
#   906,
#   2162,
#   1219,
#   1336,
#   4705,
#   171,
#   7,
#   105,
#   482,
#   473,
#   259,
#   39,
#   3334,
#   4879,
#   1463,
#   918,
#   247,
#   2857,
#   5370,
#   73,
#   2255,
#   2,
#   187,
#   645,
#   779,
#   84,
#   101,
#   731,
#   176,
#   1196,
#   317,
#   4866,
#   784,
#   5180,
#   3660,
#   283,
#   2972,
#   3313,
#   2,
#   3596,
#   2399,
#   598,
#   73,
#   2399,
#   48,
#   1510,
#   691,
#   17,
#   2691,
#   3583,
#   991,
#   1334,
#   525,
#   26,
#   3859,
#   3334,
#   4879,
#   991,
#   113,
#   4,
#   1463,
#   4160,
#   103,
#   1059,
#   55,
#   2,
#   785,
#   2197,
#   38,
#   97,
#   259,
#   1664,
#   798,
#   1544,
#   548,
#   103,
#   190,
#   292,
#   571,
#   26,
#   7,
#   873,
#   2972,
#   27,
#   5687,
#   604,
#   1661,
#   954,
#   4217,
#   691,
#   2304,
#   410,
#   1023],
#  [354,
#   3278,
#   774,
#   3669,
#   1,
#   954,
#   183,
#   2306,
#   1170,
#   1,
#   34,
#   3900,
#   322,
#   698,
#   868,
#   4592,
#   6,
#   2356,
#   97,
#   5607,
#   3254,
#   6,
#   11,
#   97,
#   358,
#   25,
#   850,
#   1052,
#   1310,
#   49,
#   3,
#   2115,
#   4705,
#   151,
#   3356,
#   1075,
#   3669,
#   45,
#   74,
#   892,
#   49,
#   662,
#   2828,
#   143,
#   2441,
#   1654,
#   48,
#   1867,
#   710,
#   16,
#   52,
#   10,
#   92,
#   74,
#   8,
#   107,
#   45,
#   97,
#   9,
#   1894,
#   369,
#   2132,
#   147,
#   651,
#   2778,
#   1027,
#   3,
#   3130,
#   124,
#   409,
#   48,
#   95,
#   123,
#   133,
#   655],
#  [1481,
#   1,
#   5006,
#   948,
#   551,
#   50,
#   4912,
#   12,
#   808,
#   44,
#   551,
#   55,
#   139,
#   13,
#   613,
#   18,
#   121,
#   5,
#   613,
#   4010,
#   3,
#   149,
#   1021,
#   54,
#   20,
#   132,
#   1,
#   159,
#   176,
#   13,
#   6,
#   22,
#   51,
#   917,
#   176,
#   226,
#   269,
#   765,
#   762,
#   1119,
#   416,
#   1,
#   613,
#   554,
#   1469,
#   4,
#   4293,
#   5438,
#   1022,
#   146,
#   4293,
#   5438,
#   1496,
#   155,
#   305,
#   617,
#   4,
#   157,
#   518,
#   131,
#   280,
#   3,
#   125,
#   78,
#   83,
#   341,
#   136,
#   490,
#   411,
#   4,
#   15,
#   884,
#   3040,
#   218,
#   4502,
#   1227,
#   2331,
#   1185,
#   3211,
#   63,
#   1496,
#   125,
#   12,
#   4,
#   342,
#   3020,
#   481,
#   83,
#   2182,
#   932,
#   159,
#   85,
#   38,
#   98,
#   481,
#   83,
#   194,
#   971,
#   849,
#   1418,
#   155,
#   13,
#   4,
#   843,
#   563,
#   16,
#   2347,
#   1723,
#   324,
#   158,
#   158,
#   2247,
#   4,
#   125,
#   1498,
#   635,
#   342,
#   3,
#   105,
#   411,
#   426,
#   71,
#   129,
#   138,
#   219,
#   1,
#   13,
#   720,
#   720,
#   21,
#   3,
#   125,
#   28,
#   163,
#   99,
#   1430,
#   28,
#   3622,
#   129,
#   509,
#   1119,
#   3,
#   125,
#   28,
#   492,
#   184,
#   1378,
#   20,
#   28,
#   4912,
#   843],
#  [493,
#   2,
#   4439,
#   493,
#   70,
#   2578,
#   1799,
#   3697,
#   18,
#   399,
#   71,
#   1343,
#   1243,
#   24,
#   4439,
#   5,
#   4644,
#   18,
#   399,
#   2,
#   2102,
#   237,
#   97,
#   5,
#   97,
#   236,
#   54,
#   8,
#   36,
#   42,
#   28,
#   456,
#   1183,
#   137,
#   304,
#   8,
#   95,
#   169,
#   85,
#   502,
#   5,
#   97,
#   5,
#   90],
#  [317,
#   1,
#   707,
#   212,
#   272,
#   16,
#   543,
#   25,
#   2,
#   634,
#   483,
#   325,
#   20,
#   21,
#   438,
#   594,
#   2,
#   2393,
#   2864,
#   3677,
#   1209,
#   59,
#   405,
#   138,
#   317,
#   76,
#   409,
#   696,
#   4581,
#   2004,
#   320,
#   1234,
#   216,
#   250,
#   5179,
#   212,
#   3,
#   589,
#   2758,
#   250,
#   1801,
#   2609,
#   1491,
#   1568,
#   409,
#   3179,
#   604,
#   45,
#   2,
#   1215,
#   2848,
#   3,
#   138,
#   2,
#   409,
#   1129,
#   138,
#   1095,
#   59,
#   151,
#   1271,
#   614,
#   2051,
#   2244,
#   3,
#   1491,
#   1568,
#   30,
#   2509,
#   155,
#   19,
#   2,
#   278,
#   948,
#   177,
#   3179,
#   62,
#   207,
#   1059,
#   800,
#   1209,
#   1928,
#   1780,
#   15,
#   117,
#   3170,
#   2150,
#   231,
#   88,
#   2,
#   474,
#   211,
#   28,
#   571,
#   952,
#   987,
#   121,
#   594,
#   1209],
#  [25,
#   4871,
#   3340,
#   25,
#   934,
#   439,
#   1444,
#   1,
#   3340,
#   181,
#   416,
#   627,
#   138,
#   185,
#   2,
#   2439,
#   4694,
#   5537,
#   4805,
#   364,
#   138,
#   1,
#   5,
#   49,
#   4158,
#   1121,
#   3340,
#   5,
#   1121,
#   5,
#   287,
#   316,
#   1389,
#   270,
#   313,
#   195,
#   11,
#   894,
#   824,
#   275,
#   23,
#   215,
#   1,
#   4,
#   181,
#   185,
#   70,
#   378,
#   162,
#   1030,
#   622,
#   964,
#   1345,
#   5444,
#   138,
#   1,
#   1679,
#   1710,
#   185],
#  [63,
#   21,
#   236,
#   5739,
#   61,
#   1898,
#   323,
#   11,
#   61,
#   1110,
#   54,
#   5739,
#   1537,
#   1166,
#   3,
#   3043,
#   4585,
#   73,
#   1387,
#   922,
#   5739,
#   4061,
#   2788,
#   33,
#   5943,
#   61,
#   144,
#   504,
#   2,
#   2207,
#   1999,
#   5739,
#   1166,
#   122,
#   116,
#   91,
#   2,
#   1019,
#   265,
#   174,
#   2174,
#   5739,
#   61,
#   33,
#   919,
#   190,
#   2,
#   1651,
#   28],
#  [56,
#   253,
#   1,
#   29,
#   79,
#   18,
#   3671,
#   160,
#   57,
#   7,
#   92,
#   213,
#   15,
#   1001,
#   3186,
#   1946,
#   4806,
#   18,
#   1279,
#   880,
#   1175,
#   1279,
#   523,
#   220,
#   78,
#   11,
#   19,
#   1131,
#   659,
#   231,
#   1435,
#   189,
#   254,
#   5018,
#   193,
#   359,
#   62,
#   5,
#   5320,
#   8,
#   232,
#   390,
#   801,
#   4898,
#   728,
#   1062,
#   19,
#   287,
#   4,
#   3835,
#   2124,
#   234,
#   378,
#   5090,
#   1241,
#   133,
#   1163],
#  [131,
#   1,
#   640,
#   91,
#   6,
#   68,
#   190,
#   1634,
#   13,
#   296,
#   1288,
#   157,
#   2023,
#   72,
#   445,
#   554,
#   162,
#   1,
#   158,
#   24,
#   21,
#   196,
#   10,
#   25,
#   53,
#   1148,
#   773,
#   162,
#   162,
#   480,
#   1,
#   749,
#   8,
#   2551,
#   180,
#   1,
#   1464,
#   2224,
#   149,
#   500,
#   128,
#   911,
#   14,
#   860,
#   2378,
#   1250,
#   40,
#   490,
#   1509,
#   2224,
#   1202,
#   1202,
#   6,
#   587,
#   37,
#   641,
#   586,
#   1261,
#   28,
#   1,
#   457,
#   1213,
#   1,
#   10,
#   3086,
#   68,
#   777,
#   199,
#   24,
#   80,
#   956,
#   13,
#   1,
#   387,
#   2885,
#   515],
#  [14,
#   1,
#   482,
#   4162,
#   548,
#   944,
#   483,
#   325,
#   35,
#   5,
#   90,
#   4728,
#   3444,
#   357,
#   483,
#   157,
#   5439,
#   3805,
#   3914,
#   4056,
#   1,
#   600,
#   3146,
#   1366,
#   974,
#   1276,
#   3034,
#   571,
#   218,
#   516,
#   277,
#   1,
#   306,
#   11,
#   1639],
#  [230,
#   6,
#   1267,
#   242,
#   1153,
#   1933,
#   2762,
#   156,
#   604,
#   1175,
#   867,
#   1097,
#   1732,
#   277,
#   1384,
#   691,
#   5759,
#   1153,
#   1138,
#   1092,
#   434,
#   475,
#   4,
#   60,
#   336,
#   1787,
#   1919,
#   2142,
#   341,
#   605,
#   17,
#   903,
#   29,
#   1576,
#   1032,
#   3690,
#   4997,
#   1381,
#   603,
#   115,
#   610,
#   556,
#   1684,
#   494,
#   4590,
#   1423,
#   1135,
#   79,
#   107,
#   1405,
#   4291,
#   2650,
#   1933,
#   1153,
#   1153,
#   1764,
#   4309,
#   4696,
#   115,
#   29,
#   1533,
#   1690,
#   245,
#   150,
#   83,
#   225,
#   1310,
#   955,
#   199,
#   565,
#   1961,
#   4959,
#   1153,
#   1555,
#   2181,
#   712,
#   409,
#   49,
#   5632,
#   3068,
#   46,
#   871,
#   1437,
#   4998,
#   2609,
#   262,
#   294,
#   352,
#   1684,
#   3066,
#   518,
#   3681,
#   38,
#   1219,
#   2005,
#   5028,
#   1271,
#   2019,
#   458,
#   435,
#   3741,
#   671,
#   1153,
#   1955,
#   1228,
#   136,
#   1036,
#   1593,
#   209,
#   182,
#   1933,
#   4221,
#   5439,
#   5180,
#   1601,
#   289,
#   57,
#   71,
#   7,
#   770,
#   5077,
#   2125,
#   968,
#   1298,
#   2978,
#   99,
#   3,
#   1020,
#   3361,
#   1736,
#   2322,
#   1548,
#   1267,
#   144,
#   434,
#   27,
#   787,
#   760,
#   1153,
#   1164,
#   828,
#   75,
#   3,
#   1423,
#   459,
#   70,
#   889,
#   1590,
#   13,
#   1270,
#   3,
#   1252,
#   1483,
#   3,
#   237,
#   1724,
#   42,
#   4309,
#   19,
#   274,
#   66,
#   1483,
#   166,
#   290,
#   2113,
#   407,
#   2561,
#   366,
#   347,
#   3379,
#   2303,
#   2867,
#   3807,
#   2240,
#   1699,
#   211,
#   477,
#   7,
#   2750,
#   552,
#   154,
#   140,
#   13,
#   731,
#   1271,
#   2019,
#   335,
#   1429,
#   3681,
#   2191,
#   1260,
#   1950,
#   462,
#   1763,
#   868,
#   808,
#   1267,
#   4689,
#   4638,
#   2536,
#   976,
#   488,
#   532,
#   224,
#   314,
#   2019,
#   3903,
#   1159,
#   5926,
#   3158,
#   34,
#   3440,
#   3462,
#   115,
#   2169,
#   242,
#   1439,
#   2019,
#   3722,
#   513,
#   563,
#   223,
#   2725,
#   565,
#   888,
#   2561,
#   238,
#   1186,
#   680,
#   4818,
#   2075,
#   889,
#   634,
#   1697,
#   2859,
#   978,
#   29,
#   163,
#   782,
#   483,
#   3,
#   4283,
#   202,
#   794,
#   1681,
#   2723,
#   1152,
#   552,
#   154,
#   1153,
#   1933,
#   2340,
#   5,
#   1477,
#   194],
#  [698,
#   132,
#   124,
#   192,
#   353,
#   6,
#   5336,
#   1905,
#   15,
#   1,
#   1182,
#   40,
#   1799,
#   255,
#   1036,
#   200,
#   21,
#   15,
#   1799,
#   55,
#   9,
#   505,
#   568,
#   3528,
#   541,
#   832,
#   480,
#   1162,
#   467,
#   2530,
#   1162,
#   508,
#   555,
#   11,
#   631,
#   1505,
#   3528,
#   973,
#   4,
#   481,
#   1505,
#   155,
#   4,
#   1,
#   244,
#   455,
#   399,
#   564,
#   1304,
#   70,
#   14,
#   422,
#   4498,
#   252,
#   7,
#   4,
#   131,
#   4119,
#   24,
#   544,
#   5,
#   174,
#   7,
#   14,
#   506,
#   59,
#   1868,
#   287,
#   389,
#   1793,
#   170,
#   73,
#   1410,
#   166,
#   1644,
#   15,
#   35,
#   95,
#   3410,
#   1215,
#   1753,
#   319,
#   237,
#   1172,
#   84],
#  ...]

# %%
totalNumWords = [len(one_comment) for one_comment in x_train_tokenized]
totalNumWords
# Out:
# [188,
#  74,
#  175,
#  132,
#  175,
#  42,
#  51,
#  56,
#  78,
#  21,
#  23,
#  67,
#  149,
#  64,
#  51,
#  89,
#  181,
#  200,
#  98,
#  53,
#  112,
#  117,
#  107,
#  21,
#  19,
#  58,
#  96,
#  110,
#  305,
#  57,
#  24,
#  57,
#  59,
#  144,
#  160,
#  144,
#  58,
#  59,
#  79,
#  218,
#  130,
#  52,
#  68,
#  65,
#  79,
#  50,
#  32,
#  49,
#  108,
#  91,
#  75,
#  42,
#  84,
#  53,
#  21,
#  60,
#  73,
#  71,
#  29,
#  175,
#  229,
#  100,
#  53,
#  69,
#  56,
#  29,
#  381,
#  28,
#  88,
#  52,
#  55,
#  183,
#  80,
#  86,
#  64,
#  65,
#  111,
#  42,
#  93,
#  60,
#  54,
#  112,
#  168,
#  75,
#  180,
#  124,
#  144,
#  24,
#  53,
#  48,
#  53,
#  45,
#  47,
#  54,
#  60,
#  68,
#  86,
#  30,
#  99,
#  37,
#  95,
#  425,
#  33,
#  74,
#  24,
#  53,
#  63,
#  73,
#  158,
#  193,
#  80,
#  92,
#  135,
#  27,
#  56,
#  112,
#  52,
#  53,
#  47,
#  57,
#  78,
#  157,
#  57,
#  112,
#  149,
#  332,
#  201,
#  140,
#  53,
#  97,
#  59,
#  252,
#  72,
#  247,
#  168,
#  9,
#  150,
#  78,
#  74,
#  55,
#  58,
#  117,
#  68,
#  70,
#  119,
#  73,
#  67,
#  126,
#  149,
#  47,
#  42,
#  71,
#  56,
#  140,
#  128,
#  43,
#  108,
#  131,
#  204,
#  73,
#  158,
#  92,
#  48,
#  58,
#  97,
#  57,
#  395,
#  65,
#  56,
#  71,
#  88,
#  91,
#  119,
#  52,
#  183,
#  62,
#  152,
#  56,
#  63,
#  103,
#  179,
#  188,
#  279,
#  51,
#  113,
#  52,
#  45,
#  167,
#  48,
#  61,
#  314,
#  50,
#  26,
#  75,
#  36,
#  108,
#  37,
#  125,
#  97,
#  43,
#  51,
#  118,
#  47,
#  113,
#  380,
#  103,
#  60,
#  92,
#  89,
#  47,
#  54,
#  247,
#  65,
#  38,
#  469,
#  45,
#  119,
#  107,
#  82,
#  53,
#  57,
#  90,
#  275,
#  37,
#  64,
#  124,
#  193,
#  45,
#  155,
#  52,
#  206,
#  144,
#  67,
#  57,
#  47,
#  170,
#  59,
#  339,
#  65,
#  62,
#  84,
#  82,
#  38,
#  234,
#  74,
#  131,
#  28,
#  93,
#  62,
#  57,
#  96,
#  103,
#  72,
#  52,
#  63,
#  306,
#  105,
#  75,
#  99,
#  87,
#  227,
#  112,
#  52,
#  133,
#  71,
#  133,
#  223,
#  68,
#  80,
#  123,
#  210,
#  47,
#  51,
#  362,
#  67,
#  143,
#  160,
#  70,
#  86,
#  81,
#  204,
#  151,
#  63,
#  123,
#  36,
#  47,
#  178,
#  117,
#  70,
#  53,
#  68,
#  66,
#  49,
#  50,
#  42,
#  90,
#  64,
#  52,
#  122,
#  209,
#  78,
#  53,
#  63,
#  61,
#  128,
#  103,
#  324,
#  245,
#  164,
#  49,
#  109,
#  128,
#  332,
#  75,
#  21,
#  126,
#  94,
#  91,
#  142,
#  19,
#  57,
#  145,
#  39,
#  86,
#  75,
#  92,
#  45,
#  32,
#  24,
#  73,
#  67,
#  88,
#  86,
#  92,
#  116,
#  132,
#  65,
#  340,
#  156,
#  88,
#  32,
#  21,
#  46,
#  90,
#  117,
#  269,
#  105,
#  51,
#  75,
#  67,
#  17,
#  120,
#  48,
#  47,
#  58,
#  162,
#  11,
#  23,
#  54,
#  60,
#  61,
#  57,
#  191,
#  244,
#  65,
#  47,
#  135,
#  73,
#  86,
#  72,
#  59,
#  64,
#  56,
#  305,
#  193,
#  230,
#  61,
#  179,
#  65,
#  132,
#  92,
#  56,
#  39,
#  46,
#  82,
#  68,
#  102,
#  79,
#  16,
#  53,
#  48,
#  278,
#  70,
#  58,
#  173,
#  58,
#  54,
#  107,
#  47,
#  97,
#  32,
#  30,
#  109,
#  120,
#  32,
#  166,
#  70,
#  46,
#  67,
#  158,
#  204,
#  113,
#  52,
#  157,
#  67,
#  37,
#  139,
#  301,
#  123,
#  60,
#  94,
#  60,
#  87,
#  272,
#  66,
#  64,
#  68,
#  99,
#  18,
#  321,
#  379,
#  89,
#  47,
#  84,
#  110,
#  77,
#  76,
#  34,
#  52,
#  85,
#  272,
#  176,
#  81,
#  84,
#  70,
#  292,
#  69,
#  65,
#  107,
#  315,
#  83,
#  92,
#  39,
#  67,
#  331,
#  56,
#  20,
#  325,
#  118,
#  99,
#  69,
#  38,
#  178,
#  137,
#  111,
#  61,
#  102,
#  58,
#  80,
#  88,
#  97,
#  67,
#  65,
#  154,
#  126,
#  47,
#  71,
#  58,
#  145,
#  160,
#  33,
#  60,
#  173,
#  59,
#  37,
#  63,
#  22,
#  37,
#  121,
#  204,
#  199,
#  79,
#  154,
#  233,
#  211,
#  73,
#  342,
#  52,
#  39,
#  121,
#  60,
#  62,
#  63,
#  58,
#  82,
#  25,
#  92,
#  60,
#  161,
#  68,
#  124,
#  121,
#  12,
#  222,
#  157,
#  23,
#  64,
#  92,
#  49,
#  67,
#  54,
#  142,
#  39,
#  100,
#  159,
#  188,
#  72,
#  128,
#  71,
#  54,
#  250,
#  95,
#  198,
#  61,
#  46,
#  57,
#  58,
#  83,
#  53,
#  257,
#  51,
#  34,
#  171,
#  130,
#  35,
#  71,
#  27,
#  168,
#  57,
#  117,
#  256,
#  77,
#  93,
#  59,
#  56,
#  38,
#  79,
#  432,
#  47,
#  45,
#  98,
#  163,
#  256,
#  54,
#  131,
#  92,
#  153,
#  66,
#  43,
#  94,
#  43,
#  55,
#  86,
#  65,
#  72,
#  24,
#  37,
#  50,
#  181,
#  149,
#  49,
#  24,
#  168,
#  47,
#  228,
#  88,
#  189,
#  80,
#  16,
#  137,
#  66,
#  152,
#  100,
#  19,
#  113,
#  46,
#  60,
#  69,
#  172,
#  163,
#  157,
#  50,
#  318,
#  83,
#  171,
#  64,
#  72,
#  80,
#  185,
#  87,
#  46,
#  81,
#  61,
#  65,
#  129,
#  107,
#  200,
#  32,
#  51,
#  153,
#  47,
#  28,
#  71,
#  37,
#  206,
#  26,
#  105,
#  52,
#  91,
#  26,
#  89,
#  40,
#  112,
#  284,
#  105,
#  58,
#  55,
#  52,
#  255,
#  216,
#  88,
#  56,
#  83,
#  34,
#  64,
#  51,
#  160,
#  56,
#  43,
#  79,
#  74,
#  56,
#  181,
#  100,
#  110,
#  91,
#  147,
#  59,
#  23,
#  81,
#  55,
#  100,
#  104,
#  47,
#  61,
#  62,
#  196,
#  53,
#  96,
#  76,
#  62,
#  164,
#  40,
#  72,
#  117,
#  85,
#  92,
#  133,
#  61,
#  106,
#  57,
#  50,
#  80,
#  88,
#  192,
#  89,
#  27,
#  113,
#  21,
#  138,
#  67,
#  35,
#  20,
#  211,
#  123,
#  56,
#  82,
#  41,
#  98,
#  46,
#  242,
#  50,
#  118,
#  19,
#  30,
#  24,
#  147,
#  66,
#  59,
#  35,
#  87,
#  65,
#  218,
#  19,
#  71,
#  62,
#  125,
#  86,
#  49,
#  59,
#  182,
#  94,
#  44,
#  135,
#  72,
#  85,
#  68,
#  32,
#  59,
#  50,
#  183,
#  150,
#  47,
#  185,
#  103,
#  260,
#  50,
#  39,
#  323,
#  128,
#  182,
#  61,
#  56,
#  54,
#  246,
#  39,
#  69,
#  96,
#  71,
#  57,
#  22,
#  151,
#  122,
#  100,
#  71,
#  156,
#  49,
#  29,
#  66,
#  64,
#  114,
#  57,
#  99,
#  39,
#  56,
#  56,
#  209,
#  116,
#  54,
#  94,
#  47,
#  59,
#  63,
#  149,
#  60,
#  52,
#  25,
#  59,
#  98,
#  111,
#  113,
#  43,
#  56,
#  158,
#  74,
#  43,
#  69,
#  110,
#  84,
#  61,
#  96,
#  461,
#  65,
#  54,
#  65,
#  87,
#  76,
#  78,
#  53,
#  114,
#  69,
#  137,
#  143,
#  77,
#  142,
#  134,
#  155,
#  140,
#  40,
#  82,
#  132,
#  57,
#  99,
#  203,
#  62,
#  39,
#  47,
#  68,
#  166,
#  83,
#  69,
#  163,
#  88,
#  61,
#  129,
#  76,
#  45,
#  25,
#  374,
#  47,
#  192,
#  26,
#  54,
#  138,
#  68,
#  166,
#  117,
#  116,
#  59,
#  131,
#  73,
#  177,
#  99,
#  40,
#  78,
#  155,
#  28,
#  39,
#  115,
#  166,
#  39,
#  229,
#  26,
#  40,
#  92,
#  56,
#  36,
#  143,
#  95,
#  158,
#  193,
#  59,
#  62,
#  65,
#  71,
#  168,
#  37,
#  79,
#  63,
#  31,
#  77,
#  84,
#  117,
#  37,
#  77,
#  45,
#  50,
#  253,
#  98,
#  106,
#  66,
#  86,
#  121,
#  109,
#  142,
#  59,
#  99,
#  175,
#  60,
#  46,
#  289,
#  35,
#  48,
#  195,
#  27,
#  89,
#  55,
#  88,
#  48,
#  54,
#  62,
#  57,
#  61,
#  126,
#  95,
#  41,
#  410,
#  23,
#  136,
#  54,
#  82,
#  332,
#  94,
#  62,
#  65,
#  54,
#  68,
#  130,
#  94,
#  78,
#  92,
#  55,
#  47,
#  61,
#  60,
#  84,
#  143,
#  185,
#  54,
#  137,
#  111,
#  27,
#  82,
#  57,
#  290,
#  68,
#  56,
#  69,
#  201,
#  48,
#  65,
#  90,
#  98,
#  82,
#  133,
#  75,
#  86,
#  127,
#  80,
#  65,
#  104,
#  267,
#  63,
#  80,
#  53,
#  109,
#  296,
#  198,
#  79,
#  45,
#  78,
#  86,
#  257,
#  68,
#  94,
#  199,
#  244,
#  103,
#  141,
#  83,
#  54,
#  66,
#  48,
#  313,
#  105,
#  26,
#  253,
#  108,
#  68,
#  97,
#  137,
#  96,
#  124,
#  138,
#  78,
#  64,
#  95,
#  101,
#  137,
#  75,
#  151,
#  44,
#  99,
#  59,
#  49,
#  57,
#  76,
#  35,
#  255,
#  85,
#  ...]

# %%
totalNumWords = [len(one_sentence) for one_sentence in x_train_tokenized]
plt.hist(totalNumWords, bins = np.arange(0,410,10))
plt.xlabel("no of words")
plt.ylabel("no of comments")
plt.title("No of word distribution of comment")
plt.show()
print("Total comments =", len(x_train_tokenized))
# Out:
# Total comments = 25000

# %% [markdown]
# # 2) Padding

# %%
# Padding (making every comments in same length)

maxlen = 250
x_train = pad_sequences(x_train_tokenized, maxlen = maxlen)
x_test = pad_sequences(x_test_tokenized, maxlen = maxlen)

# %%
print('len(x_train):', len(x_train))
x_train
# Out:
# len(x_train): 25000
# array([[   0,    0,    0, ...,    3,  316, 1356],
#        [   0,    0,    0, ..., 4628, 1251, 5471],
#        [   0,    0,    0, ...,  700, 1175, 5310],
#        ...,
#        [   0,    0,    0, ...,   10,   14,  207],
#        [   0,    0,    0, ...,  218, 1903,   16],
#        [   0,    0,    0, ..., 1108,  109,  350]])

# %% [markdown]
# # Split training and valdiation set

# %%
from sklearn.model_selection import train_test_split

x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.1, random_state=0)

# %% [markdown]
# # LSTM

# %%
from keras.models import Sequential
from keras.layers import Dense , Input , LSTM , Embedding, Dropout , Activation
from keras.layers import Bidirectional, GlobalMaxPool1D
from keras.models import Model
from keras import initializers, regularizers, constraints, optimizers, layers

# %% [markdown]
# ## 1) Define model architecture & Compile

# %%
embed_size = 128

def Create_model ():

    model = Sequential()
    model.add(Embedding(
        input_dim = max_features,   #6000
        output_dim = embed_size,    #128
        input_length = maxlen,      #250
        trainable = False))
    
    model.add(Bidirectional(LSTM(64, return_sequences=True, recurrent_dropout=0.1)))
    model.add(GlobalMaxPool1D())
    model.add(Dropout(0.25))
    
    model.add(Dense(50, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(1, activation='sigmoid'))
    model.summary()
    
    model.compile(
        loss="binary_crossentropy",
        optimizer='adam',
        metrics=['accuracy'])
    
    return model

# %%
model = Create_model()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0902 21:37:44.759414 17112 deprecation_wrapper.py:119] From D:\Anaconda3\envs\tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0902 21:37:44.778396 17112 deprecation_wrapper.py:119] From D:\Anaconda3\envs\tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0902 21:37:44.781356 17112 deprecation_wrapper.py:119] From D:\Anaconda3\envs\tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0902 21:37:44.899040 17112 deprecation_wrapper.py:119] From D:\Anaconda3\envs\tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0902 21:37:44.909013 17112 deprecation.py:506] From D:\Anaconda3\envs\tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0902 21:37:45.401697 17112 deprecation_wrapper.py:119] From D:\Anaconda3\envs\tensorflow\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0902 21:37:45.425634 17112 deprecation_wrapper.py:119] From D:\Anaconda3\envs\tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0902 21:37:45.429651 17112 deprecation.py:323] From D:\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 250, 128)          768000
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 250, 128)          98816
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 128)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                6450
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 873,317
# Trainable params: 105,317
# Non-trainable params: 768,000
# _________________________________________________________________

# %%
# load model weights
# model.load_weights('./model/modelweights.h5')

# %%
history = model.fit(x = x_train, y = y_train, epochs = 20, batch_size = 64,
                    validation_data = (x_val, y_val))
# Out:
# Train on 22500 samples, validate on 2500 samples
# Epoch 1/20
# 22500/22500 [==============================] - 254s 11ms/step - loss: 0.6637 - acc: 0.5922 - val_loss: 0.6051 - val_acc: 0.7100
# Epoch 2/20
# 22500/22500 [==============================] - 291s 13ms/step - loss: 0.5691 - acc: 0.7078 - val_loss: 0.5052 - val_acc: 0.7648
# Epoch 3/20
# 22500/22500 [==============================] - 277s 12ms/step - loss: 0.4958 - acc: 0.7595 - val_loss: 0.4454 - val_acc: 0.7976
# Epoch 4/20
# 22500/22500 [==============================] - 276s 12ms/step - loss: 0.4529 - acc: 0.7869 - val_loss: 0.4305 - val_acc: 0.8000
# Epoch 5/20
# 22500/22500 [==============================] - 271s 12ms/step - loss: 0.4192 - acc: 0.8107 - val_loss: 0.3944 - val_acc: 0.8224
# Epoch 6/20
# 22500/22500 [==============================] - 244s 11ms/step - loss: 0.3929 - acc: 0.8240 - val_loss: 0.3796 - val_acc: 0.8304
# Epoch 7/20
# 22500/22500 [==============================] - 265s 12ms/step - loss: 0.3686 - acc: 0.8356 - val_loss: 0.3718 - val_acc: 0.8296
# Epoch 8/20
# 22500/22500 [==============================] - 295s 13ms/step - loss: 0.3483 - acc: 0.8489 - val_loss: 0.3707 - val_acc: 0.8296
# Epoch 9/20
# 22500/22500 [==============================] - 279s 12ms/step - loss: 0.3278 - acc: 0.8628 - val_loss: 0.3598 - val_acc: 0.8388
# Epoch 10/20
# 22500/22500 [==============================] - 275s 12ms/step - loss: 0.3193 - acc: 0.8630 - val_loss: 0.3498 - val_acc: 0.8456
# Epoch 11/20
# 22500/22500 [==============================] - 289s 13ms/step - loss: 0.3083 - acc: 0.8706 - val_loss: 0.3690 - val_acc: 0.8328
# Epoch 12/20
# 22500/22500 [==============================] - 281s 12ms/step - loss: 0.2921 - acc: 0.8768 - val_loss: 0.3399 - val_acc: 0.8520
# Epoch 13/20
# 22500/22500 [==============================] - 276s 12ms/step - loss: 0.2765 - acc: 0.8868 - val_loss: 0.3526 - val_acc: 0.8484
# Epoch 14/20
# 22500/22500 [==============================] - 284s 13ms/step - loss: 0.2702 - acc: 0.8894 - val_loss: 0.3434 - val_acc: 0.8544
# Epoch 15/20
# 22500/22500 [==============================] - 294s 13ms/step - loss: 0.2623 - acc: 0.8915 - val_loss: 0.3370 - val_acc: 0.8564
# Epoch 16/20
# 22500/22500 [==============================] - 271s 12ms/step - loss: 0.2552 - acc: 0.8937 - val_loss: 0.3402 - val_acc: 0.8520
# Epoch 17/20
# 22500/22500 [==============================] - 275s 12ms/step - loss: 0.2425 - acc: 0.9005 - val_loss: 0.3433 - val_acc: 0.8544
# Epoch 18/20
# 22500/22500 [==============================] - 279s 12ms/step - loss: 0.2319 - acc: 0.9056 - val_loss: 0.3471 - val_acc: 0.8540
# Epoch 19/20
# 22500/22500 [==============================] - 244s 11ms/step - loss: 0.2274 - acc: 0.9099 - val_loss: 0.3435 - val_acc: 0.8552
# Epoch 20/20
# 22500/22500 [==============================] - 245s 11ms/step - loss: 0.2166 - acc: 0.9131 - val_loss: 0.3566 - val_acc: 0.8572

# %%
print(history.history.keys())
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %% [markdown]
# # Model Evaluation (df_train)

# %% [markdown]
# ## 1) Plot loss and accuracy

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.title('Model accuracy')
plt.ylabel('accuracy')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# ## 2) Loss and accuracy on validation set

# %%
score = model.evaluate(x_val, y_val)
print("loss:", score[0])
print("metric (accuracy): ", score[1])
# Out:
# 2500/2500 [==============================] - 4s 2ms/step
# loss: 0.356595374751091
# metric (accuracy):  0.8572

# %% [markdown]
# ## 3) ROC AUC

# %%
y_train_pred = model.predict_classes(x_train)
y_val_pred = model.predict_classes(x_val)

# %%
from sklearn.metrics import roc_auc_score

print('ROC AUC (train): {0}'.format(roc_auc_score(y_train, y_train_pred)))
print('ROC AUC (val): {0}'.format(roc_auc_score(y_val, y_val_pred)))
# Out:
# ROC AUC (train): 0.9554044873915004
# ROC AUC (val): 0.858379055866777

# %% [markdown]
# ## 4) Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(y_true, y_pred, ax, class_names, vmax=None,
                          normed=True, title='Confusion matrix'):
    matrix = confusion_matrix(y_true,y_pred)
    if normed:
        matrix = matrix.astype('float') / matrix.sum(axis=1)[:, np.newaxis]
    sns.heatmap(matrix, vmax=vmax, annot=True, square=True, ax=ax,
               cmap=plt.cm.Blues_r, cbar=False, linecolor='black',
               linewidths=1, xticklabels=class_names)
    ax.set_title(title, y=1.20, fontsize=16)
    #ax.set_ylabel('True labels', fontsize=12)
    ax.set_xlabel('Predicted labels', y=1.10, fontsize=12)
    ax.set_yticklabels(class_names, rotation=0)

# %%
fig, (axis1, axis2) = plt.subplots(nrows=1, ncols=2)
plot_confusion_matrix(y_train, y_train_pred, ax=axis1,
                      title='Confusion matrix (train data)',
                      class_names=['Positive', 'Negative'])

plot_confusion_matrix(y_val, y_val_pred, ax=axis2,
                      title='Confusion matrix (val data)',
                      class_names=['Positive', 'Negative'])

# %% [markdown]
# # Prediction (x_test)

# %%
y_test_pred = model.predict_classes(x_test)

# %%
y_test_pred
# Out:
# array([[1],
#        [0],
#        [1],
#        ...,
#        [1],
#        [1],
#        [1]])

# %%
submission = pd.read_csv("./input/sampleSubmission.csv")
submission['sentiment'] = y_test_pred.astype(int)
submission.to_csv('./output/submission_words.csv', index=False)

# %% [markdown]
# # Save model architecture (.json) and model weights (.h5)

# %%
# Save model architecture (.json)

model_json = model.to_json()
with open("./model/modelarchitecture.json", "w") as json_file:
    json_file.write(model_json)

# %%
# Save model weights (.h5)

model.save_weights("./model/modelweights.h5")

# %% [markdown]
# # Plot Model png

# %%
from keras.utils import plot_model
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

plot_model(model, to_file='./model/model.png')
SVG(model_to_dot(model).create(prog='dot', format='svg'))
